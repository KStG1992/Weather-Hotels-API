# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
#Building Query URL
query_url = f"{base_url}appid={weather_api_key}&q="

# %%
city_wx = []
lat = []
lon = []
maxTemp = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

record_count = 1
set_count = 1

print('Beginning Data Retrieval')
print('------------------------')
for city in cities:
    if record_count >= 50:
        time.sleep(60)
        record_count = 0
        set_count += 1
    
    response = requests.get(query_url + city + '&units=imperial').json()
    record_count += 1
    
    try:
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_wx.append(city)
        print(f'Processing Record {record_count} of Set {set_count} | {city}')
    except KeyError:
        print('City not found. Skipping...')
print('------------------------')
print('Data Retrieval Complete')
print('------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | leningradskiy
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | svetlogorsk
# Processing Record 8 of Set 1 | half moon bay
# Processing Record 9 of Set 1 | aksu
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | khairagarh
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | vitim
# Processing Record 14 of Set 1 | concordia
# Processing Record 15 of Set 1 | nador
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | berlevag
# City not found. Skipping...
# Processing Record 19 of Set 1 | genhe
# City not found. Skipping...
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | loutra
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | shubarkuduk
# City not found. Skipping...
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | mitsamiouli
# Processing Record 28 of Set 1 | saint-augustin
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | port-gentil
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | amahai
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | abu samrah
# Processing Record 36 of Set 1 | carmen
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | oranjemund
# Processing Record 43 of Set 1 | roblin
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | cowra
# Processing Record 46 of Set 1 | dongfeng
# Processing Record 47 of Set 1 | totolapa
# Processing Record 48 of Set 1 | provideniya
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | mount gambier
# Processing Record 2 of Set 2 | monrovia
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | bathsheba
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | pascagoula
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | osoyoos
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | havoysund
# City not found. Skipping...
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | mehamn
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | toamasina
# Processing Record 18 of Set 2 | khandyga
# City not found. Skipping...
# Processing Record 20 of Set 2 | coyutla
# Processing Record 21 of Set 2 | ler
# Processing Record 22 of Set 2 | bosaso
# Processing Record 23 of Set 2 | amapa
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | ferkessedougou
# Processing Record 26 of Set 2 | lasa
# Processing Record 27 of Set 2 | san carlos de bariloche
# Processing Record 28 of Set 2 | kidal
# Processing Record 29 of Set 2 | sitka
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | egvekinot
# Processing Record 35 of Set 2 | corrales
# Processing Record 36 of Set 2 | lichtenburg
# Processing Record 37 of Set 2 | williston
# Processing Record 38 of Set 2 | heihe
# Processing Record 39 of Set 2 | busselton
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | aswan
# Processing Record 42 of Set 2 | grindavik
# Processing Record 43 of Set 2 | brae
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | chiredzi
# Processing Record 46 of Set 2 | ribeira grande
# Processing Record 47 of Set 2 | kaeo
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | humaita
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | orbetello
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | nouadhibou
# Processing Record 7 of Set 3 | jishu
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | kavaratti
# Processing Record 10 of Set 3 | nome
# Processing Record 11 of Set 3 | broome
# Processing Record 12 of Set 3 | olinda
# Processing Record 13 of Set 3 | pangody
# Processing Record 14 of Set 3 | fort dodge
# Processing Record 15 of Set 3 | nanning
# Processing Record 16 of Set 3 | vao
# Processing Record 17 of Set 3 | maniitsoq
# Processing Record 18 of Set 3 | chicama
# Processing Record 19 of Set 3 | cidreira
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | arman
# Processing Record 22 of Set 3 | san policarpo
# Processing Record 23 of Set 3 | srednekolymsk
# Processing Record 24 of Set 3 | colquechaca
# Processing Record 25 of Set 3 | siverskiy
# Processing Record 26 of Set 3 | noumea
# Processing Record 27 of Set 3 | komsomolskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | dudinka
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | herat
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | port blair
# Processing Record 36 of Set 3 | joetsu
# Processing Record 37 of Set 3 | pahrump
# Processing Record 38 of Set 3 | newton
# Processing Record 39 of Set 3 | marsabit
# Processing Record 40 of Set 3 | marawi
# City not found. Skipping...
# Processing Record 42 of Set 3 | havelock
# City not found. Skipping...
# Processing Record 44 of Set 3 | doha
# Processing Record 45 of Set 3 | danjiangkou
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | inuvik
# Processing Record 48 of Set 3 | henties bay
# Processing Record 49 of Set 3 | olafsvik
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | rabo de peixe
# Processing Record 2 of Set 4 | palmer
# Processing Record 3 of Set 4 | gornopravdinsk
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | pouembout
# Processing Record 6 of Set 4 | husavik
# Processing Record 7 of Set 4 | puerto baquerizo moreno
# Processing Record 8 of Set 4 | sisimiut
# Processing Record 9 of Set 4 | teguldet
# Processing Record 10 of Set 4 | cortez
# Processing Record 11 of Set 4 | shakawe
# Processing Record 12 of Set 4 | cozumel
# Processing Record 13 of Set 4 | kalmunai
# Processing Record 14 of Set 4 | cakovec
# Processing Record 15 of Set 4 | iqaluit
# City not found. Skipping...
# Processing Record 17 of Set 4 | nongstoin
# Processing Record 18 of Set 4 | mandan
# Processing Record 19 of Set 4 | patnanungan
# Processing Record 20 of Set 4 | comodoro rivadavia
# Processing Record 21 of Set 4 | sechura
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | chapais
# Processing Record 24 of Set 4 | mukhen
# Processing Record 25 of Set 4 | karaton
# Processing Record 26 of Set 4 | tres arroyos
# Processing Record 27 of Set 4 | srandakan
# Processing Record 28 of Set 4 | teya
# Processing Record 29 of Set 4 | ola
# Processing Record 30 of Set 4 | khani
# Processing Record 31 of Set 4 | gat
# Processing Record 32 of Set 4 | taman
# Processing Record 33 of Set 4 | zhangye
# Processing Record 34 of Set 4 | adre
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | shizunai
# Processing Record 39 of Set 4 | fairbanks
# Processing Record 40 of Set 4 | kroya
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | okha
# Processing Record 43 of Set 4 | yagodnoye
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | alta floresta
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | saint-philippe
# Processing Record 48 of Set 4 | vostok
# Processing Record 49 of Set 4 | buique
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | blagoyevo
# Processing Record 2 of Set 5 | novara
# Processing Record 3 of Set 5 | keti bandar
# Processing Record 4 of Set 5 | bilibino
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | bandarbeyla
# Processing Record 7 of Set 5 | sola
# Processing Record 8 of Set 5 | butaritari
# Processing Record 9 of Set 5 | bertoua
# Processing Record 10 of Set 5 | borovoy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 5 | burgeo
# Processing Record 14 of Set 5 | jaru
# Processing Record 15 of Set 5 | college
# Processing Record 16 of Set 5 | samarai
# Processing Record 17 of Set 5 | saint anthony
# Processing Record 18 of Set 5 | antalaha
# Processing Record 19 of Set 5 | asyut
# City not found. Skipping...
# Processing Record 21 of Set 5 | sidi ali
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | maceio
# Processing Record 24 of Set 5 | jinxiang
# Processing Record 25 of Set 5 | bhainsdehi
# Processing Record 26 of Set 5 | vanavara
# Processing Record 27 of Set 5 | korbach
# Processing Record 28 of Set 5 | pangnirtung
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | atuona
# Processing Record 31 of Set 5 | vila
# Processing Record 32 of Set 5 | yenangyaung
# City not found. Skipping...
# Processing Record 34 of Set 5 | ponta do sol
# Processing Record 35 of Set 5 | lebu
# Processing Record 36 of Set 5 | lompoc
# Processing Record 37 of Set 5 | damghan
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | letenye
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | tabuk
# Processing Record 43 of Set 5 | bardiyah
# Processing Record 44 of Set 5 | bereda
# Processing Record 45 of Set 5 | sioux lookout
# Processing Record 46 of Set 5 | hurghada
# Processing Record 47 of Set 5 | evensk
# Processing Record 48 of Set 5 | nevinnomyssk
# Processing Record 49 of Set 5 | dharchula
# Processing Record 50 of Set 5 | quartucciu
# City not found. Skipping...
# Processing Record 2 of Set 6 | la ronge
# Processing Record 3 of Set 6 | tzucacab
# City not found. Skipping...
# Processing Record 5 of Set 6 | bitung
# Processing Record 6 of Set 6 | ilulissat
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | ustrzyki dolne
# Processing Record 9 of Set 6 | fort saint james
# Processing Record 10 of Set 6 | odienne
# Processing Record 11 of Set 6 | sao jose da coroa grande
# Processing Record 12 of Set 6 | diamantino
# City not found. Skipping...
# Processing Record 14 of Set 6 | le port
# Processing Record 15 of Set 6 | kloulklubed
# Processing Record 16 of Set 6 | tuy hoa
# Processing Record 17 of Set 6 | sijunjung
# Processing Record 18 of Set 6 | daru
# Processing Record 19 of Set 6 | khatanga
# Processing Record 20 of Set 6 | tabou
# Processing Record 21 of Set 6 | inta
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | springbok
# Processing Record 24 of Set 6 | nelson bay
# Processing Record 25 of Set 6 | mahon
# Processing Record 26 of Set 6 | saskylakh
# Processing Record 27 of Set 6 | flinders
# City not found. Skipping...
# Processing Record 29 of Set 6 | santa pola
# Processing Record 30 of Set 6 | saldanha
# Processing Record 31 of Set 6 | port hawkesbury
# Processing Record 32 of Set 6 | caravelas
# Processing Record 33 of Set 6 | marienburg
# Processing Record 34 of Set 6 | lucapa
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | pakxe
# Processing Record 37 of Set 6 | lata
# City not found. Skipping...
# Processing Record 39 of Set 6 | yulara
# Processing Record 40 of Set 6 | fukue
# Processing Record 41 of Set 6 | san patricio
# Processing Record 42 of Set 6 | opuwo
# Processing Record 43 of Set 6 | saurimo
# Processing Record 44 of Set 6 | sao filipe
# City not found. Skipping...
# Processing Record 46 of Set 6 | yantal
# Processing Record 47 of Set 6 | sept-iles
# Processing Record 48 of Set 6 | bontang
# Processing Record 49 of Set 6 | hami
# Processing Record 50 of Set 6 | pevek
# Processing Record 1 of Set 7 | kinarut
# Processing Record 2 of Set 7 | tiznit
# Processing Record 3 of Set 7 | basco
# Processing Record 4 of Set 7 | thompson
# Processing Record 5 of Set 7 | pimentel
# Processing Record 6 of Set 7 | isangel
# Processing Record 7 of Set 7 | chachapoyas
# Processing Record 8 of Set 7 | panama city
# Processing Record 9 of Set 7 | grand gaube
# Processing Record 10 of Set 7 | sao joao da barra
# Processing Record 11 of Set 7 | southwick
# Processing Record 12 of Set 7 | chokurdakh
# Processing Record 13 of Set 7 | quatre cocos
# Processing Record 14 of Set 7 | bengkulu
# Processing Record 15 of Set 7 | borba
# Processing Record 16 of Set 7 | zhigansk
# Processing Record 17 of Set 7 | usevya
# Processing Record 18 of Set 7 | euclides da cunha
# Processing Record 19 of Set 7 | puerto leguizamo
# Processing Record 20 of Set 7 | beringovskiy
# Processing Record 21 of Set 7 | rio gallegos
# Processing Record 22 of Set 7 | dikson
# Processing Record 23 of Set 7 | cordele
# Processing Record 24 of Set 7 | wakuya
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | cam ranh
# Processing Record 27 of Set 7 | tuatapere
# Processing Record 28 of Set 7 | wake forest
# City not found. Skipping...
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | xining
# Processing Record 32 of Set 7 | tondano
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | mount isa
# Processing Record 35 of Set 7 | olenegorsk
# Processing Record 36 of Set 7 | luwuk
# Processing Record 37 of Set 7 | oxapampa
# Processing Record 38 of Set 7 | rawson
# Processing Record 39 of Set 7 | zhongshu
# Processing Record 40 of Set 7 | chokwe
# Processing Record 41 of Set 7 | bubaque
# Processing Record 42 of Set 7 | avarua
# Processing Record 43 of Set 7 | mayna
# Processing Record 44 of Set 7 | hazebrouck
# Processing Record 45 of Set 7 | vouliagmeni
# Processing Record 46 of Set 7 | severo-yeniseyskiy
# Processing Record 47 of Set 7 | uvira
# Processing Record 48 of Set 7 | tabora
# Processing Record 49 of Set 7 | saint-leu
# Processing Record 50 of Set 7 | ganzhou
# Processing Record 1 of Set 8 | bonthe
# Processing Record 2 of Set 8 | troitskoye
# Processing Record 3 of Set 8 | ambunti
# Processing Record 4 of Set 8 | sri aman
# Processing Record 5 of Set 8 | muscat
# City not found. Skipping...
# Processing Record 7 of Set 8 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 9 of Set 8 | riyadh
# Processing Record 10 of Set 8 | sobolevo
# Processing Record 11 of Set 8 | belousovka
# Processing Record 12 of Set 8 | pathalgaon
# Processing Record 13 of Set 8 | abha
# City not found. Skipping...
# Processing Record 15 of Set 8 | waitati
# Processing Record 16 of Set 8 | umreth
# Processing Record 17 of Set 8 | derbent
# Processing Record 18 of Set 8 | lesogorsk
# Processing Record 19 of Set 8 | susangerd
# Processing Record 20 of Set 8 | udachnyy
# Processing Record 21 of Set 8 | fuling
# Processing Record 22 of Set 8 | kargasok
# Processing Record 23 of Set 8 | tarko-sale
# Processing Record 24 of Set 8 | kanniyakumari
# Processing Record 25 of Set 8 | camana
# Processing Record 26 of Set 8 | issoudun
# Processing Record 27 of Set 8 | ponta pora
# Processing Record 28 of Set 8 | wufeng
# Processing Record 29 of Set 8 | ahipara
# Processing Record 30 of Set 8 | brookhaven
# Processing Record 31 of Set 8 | xuanzhou
# Processing Record 32 of Set 8 | milkovo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 8 | alice springs
# Processing Record 36 of Set 8 | tilichiki
# Processing Record 37 of Set 8 | podgornoye
# Processing Record 38 of Set 8 | corsicana
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | hohhot
# Processing Record 41 of Set 8 | indianola
# Processing Record 42 of Set 8 | hay river
# Processing Record 43 of Set 8 | dalby
# Processing Record 44 of Set 8 | saint george
# Processing Record 45 of Set 8 | grand forks
# Processing Record 46 of Set 8 | maniwaki
# Processing Record 47 of Set 8 | xiaoweizhai
# Processing Record 48 of Set 8 | atar
# Processing Record 49 of Set 8 | taltal
# Processing Record 50 of Set 8 | zhezkazgan
# Processing Record 1 of Set 9 | kruisfontein
# Processing Record 2 of Set 9 | itarema
# Processing Record 3 of Set 9 | wahiawa
# Processing Record 4 of Set 9 | kentau
# Processing Record 5 of Set 9 | newport
# Processing Record 6 of Set 9 | omidiyeh
# Processing Record 7 of Set 9 | vallenar
# Processing Record 8 of Set 9 | horta
# Processing Record 9 of Set 9 | manaure
# Processing Record 10 of Set 9 | prescott valley
# Processing Record 11 of Set 9 | cangzhou
# Processing Record 12 of Set 9 | cabedelo
# Processing Record 13 of Set 9 | ozark
# Processing Record 14 of Set 9 | yar-sale
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | saint-georges
# City not found. Skipping...
# Processing Record 18 of Set 9 | muisne
# Processing Record 19 of Set 9 | athens
# Processing Record 20 of Set 9 | mackay
# City not found. Skipping...
# Processing Record 22 of Set 9 | enumclaw
# Processing Record 23 of Set 9 | furstenwalde
# Processing Record 24 of Set 9 | phan thiet
# Processing Record 25 of Set 9 | kijang
# Processing Record 26 of Set 9 | upernavik
# Processing Record 27 of Set 9 | margate
# Processing Record 28 of Set 9 | qixingtai
# Processing Record 29 of Set 9 | kieta
# Processing Record 30 of Set 9 | jibuti
# Processing Record 31 of Set 9 | mayor pablo lagerenza
# Processing Record 32 of Set 9 | dendermonde
# Processing Record 33 of Set 9 | caranavi
# Processing Record 34 of Set 9 | sosnovo-ozerskoye
# Processing Record 35 of Set 9 | nioro
# Processing Record 36 of Set 9 | hambantota
# Processing Record 37 of Set 9 | acarau
# Processing Record 38 of Set 9 | touros
# Processing Record 39 of Set 9 | porto novo
# Processing Record 40 of Set 9 | suez
# Processing Record 41 of Set 9 | pereslavl-zalesskiy
# Processing Record 42 of Set 9 | koulamoutou
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | tijara
# Processing Record 45 of Set 9 | bambous virieux
# Processing Record 46 of Set 9 | guanica
# Processing Record 47 of Set 9 | kedrovyy
# Processing Record 48 of Set 9 | mahina
# City not found. Skipping...
# Processing Record 50 of Set 9 | ligourion
# Processing Record 1 of Set 10 | taft
# Processing Record 2 of Set 10 | muncar
# Processing Record 3 of Set 10 | placido de castro
# Processing Record 4 of Set 10 | gummidipundi
# Processing Record 5 of Set 10 | saint cloud
# Processing Record 6 of Set 10 | fort nelson
# Processing Record 7 of Set 10 | geraldton
# Processing Record 8 of Set 10 | kahului
# Processing Record 9 of Set 10 | tshikapa
# Processing Record 10 of Set 10 | novocheremshansk
# Processing Record 11 of Set 10 | liku
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 10 | puerto montt
# Processing Record 16 of Set 10 | okhotsk
# Processing Record 17 of Set 10 | oistins
# Processing Record 18 of Set 10 | mildura
# City not found. Skipping...
# Processing Record 20 of Set 10 | camacha
# City not found. Skipping...
# Processing Record 22 of Set 10 | tenamaxtlan
# Processing Record 23 of Set 10 | najran
# Processing Record 24 of Set 10 | payette
# Processing Record 25 of Set 10 | lubaczow
# Processing Record 26 of Set 10 | asau
# Processing Record 27 of Set 10 | huarmey
# Processing Record 28 of Set 10 | manuk mangkaw
# City not found. Skipping...
# Processing Record 30 of Set 10 | lima
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | cururupu
# Processing Record 33 of Set 10 | nhulunbuy
# Processing Record 34 of Set 10 | alihe
# City not found. Skipping...
# Processing Record 36 of Set 10 | namtsy
# Processing Record 37 of Set 10 | petropavl
# Processing Record 38 of Set 10 | jati
# Processing Record 39 of Set 10 | ust-tsilma
# Processing Record 40 of Set 10 | pindi bhattian
# Processing Record 41 of Set 10 | oktyabrskiy
# Processing Record 42 of Set 10 | cayenne
# Processing Record 43 of Set 10 | ocean city
# Processing Record 44 of Set 10 | itapora
# Processing Record 45 of Set 10 | hwange
# Processing Record 46 of Set 10 | qasigiannguit
# Processing Record 47 of Set 10 | koutiala
# Processing Record 48 of Set 10 | ankang
# Processing Record 49 of Set 10 | safaga
# Processing Record 50 of Set 10 | souillac
# Processing Record 1 of Set 11 | mandalgovi
# Processing Record 2 of Set 11 | hamburg
# Processing Record 3 of Set 11 | bol
# Processing Record 4 of Set 11 | kiruna
# Processing Record 5 of Set 11 | isiro
# Processing Record 6 of Set 11 | boffa
# Processing Record 7 of Set 11 | hualmay
# Processing Record 8 of Set 11 | pundaguitan
# Processing Record 9 of Set 11 | quattro castella
# Processing Record 10 of Set 11 | dawlatabad
# Processing Record 11 of Set 11 | benguela
# Processing Record 12 of Set 11 | bonavista
# Processing Record 13 of Set 11 | minab
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | san cristobal
# Processing Record 16 of Set 11 | general roca
# Processing Record 17 of Set 11 | borgo san lorenzo
# Processing Record 18 of Set 11 | maraba
# Processing Record 19 of Set 11 | retz
# Processing Record 20 of Set 11 | port macquarie
# Processing Record 21 of Set 11 | luderitz
# Processing Record 22 of Set 11 | ulaangom
# City not found. Skipping...
# Processing Record 24 of Set 11 | mbanza-ngungu
# Processing Record 25 of Set 11 | luau
# Processing Record 26 of Set 11 | jiayuguan
# Processing Record 27 of Set 11 | ardakan
# Processing Record 28 of Set 11 | corozal
# Processing Record 29 of Set 11 | warren
# Processing Record 30 of Set 11 | batagay-alyta
# Processing Record 31 of Set 11 | kozan
# Processing Record 32 of Set 11 | te anau
# Processing Record 33 of Set 11 | lanciano
# Processing Record 34 of Set 11 | ereymentau
# Processing Record 35 of Set 11 | flin flon
# Processing Record 36 of Set 11 | barga
# Processing Record 37 of Set 11 | port lincoln
# Processing Record 38 of Set 11 | buin
# City not found. Skipping...
# Processing Record 40 of Set 11 | nabire
# Processing Record 41 of Set 11 | tura
# Processing Record 42 of Set 11 | santa fe
# Processing Record 43 of Set 11 | diffa
# Processing Record 44 of Set 11 | sibolga
# Processing Record 45 of Set 11 | sakyla
# City not found. Skipping...
# Processing Record 47 of Set 11 | lac du bonnet
# Processing Record 48 of Set 11 | krasnoselkup
# City not found. Skipping...
# Processing Record 50 of Set 11 | abu kamal
# Processing Record 1 of Set 12 | vanimo
# Processing Record 2 of Set 12 | taunggyi
# City not found. Skipping...
# Processing Record 4 of Set 12 | nago
# Processing Record 5 of Set 12 | novyy urengoy
# Processing Record 6 of Set 12 | korla
# City not found. Skipping...
# Processing Record 8 of Set 12 | manassas park
# Processing Record 9 of Set 12 | tual
# Processing Record 10 of Set 12 | san ignacio
# Processing Record 11 of Set 12 | khulo
# Processing Record 12 of Set 12 | manta
# Processing Record 13 of Set 12 | batticaloa
# Processing Record 14 of Set 12 | pavlogradka
# Processing Record 15 of Set 12 | methoni
# Processing Record 16 of Set 12 | faya
# Processing Record 17 of Set 12 | kayerkan
# Processing Record 18 of Set 12 | saint-pierre
# Processing Record 19 of Set 12 | barstow
# Processing Record 20 of Set 12 | xichang
# Processing Record 21 of Set 12 | lakes entrance
# City not found. Skipping...
# Processing Record 23 of Set 12 | vung tau
# Processing Record 24 of Set 12 | novosheshminsk
# Processing Record 25 of Set 12 | muros
# Processing Record 26 of Set 12 | ndele
# Processing Record 27 of Set 12 | tanout
# Processing Record 28 of Set 12 | kenai
# Processing Record 29 of Set 12 | alice
# Processing Record 30 of Set 12 | okato
# City not found. Skipping...
# Processing Record 32 of Set 12 | sapouy
# Processing Record 33 of Set 12 | richards bay
# Processing Record 34 of Set 12 | graz
# Processing Record 35 of Set 12 | mount pleasant
# Processing Record 36 of Set 12 | fairview
# Processing Record 37 of Set 12 | pipar
# Processing Record 38 of Set 12 | nadym
# Processing Record 39 of Set 12 | chernyshkovskiy
# Processing Record 40 of Set 12 | mujiayingzi
# Processing Record 41 of Set 12 | segezha
# Processing Record 42 of Set 12 | botwood
# Processing Record 43 of Set 12 | khilok
# Processing Record 44 of Set 12 | goedereede
# Processing Record 45 of Set 12 | poum
# Processing Record 46 of Set 12 | port hedland
# Processing Record 47 of Set 12 | morondava
# Processing Record 48 of Set 12 | kindu
# City not found. Skipping...
# Processing Record 50 of Set 12 | coahuayana
# Processing Record 1 of Set 13 | tamale
# Processing Record 2 of Set 13 | pinheiro machado
# Processing Record 3 of Set 13 | along
# Processing Record 4 of Set 13 | ojinaga
# Processing Record 5 of Set 13 | loukhi
# Processing Record 6 of Set 13 | tahta
# Processing Record 7 of Set 13 | saurikh
# Processing Record 8 of Set 13 | pleshanovo
# City not found. Skipping...
# Processing Record 10 of Set 13 | gigmoto
# Processing Record 11 of Set 13 | torata
# Processing Record 12 of Set 13 | lahad datu
# Processing Record 13 of Set 13 | churapcha
# Processing Record 14 of Set 13 | eganville
# City not found. Skipping...
# Processing Record 16 of Set 13 | svobodnyy
# Processing Record 17 of Set 13 | kovdor
# Processing Record 18 of Set 13 | statesboro
# Processing Record 19 of Set 13 | nakamura
# Processing Record 20 of Set 13 | ternate
# Processing Record 21 of Set 13 | teguise
# Processing Record 22 of Set 13 | corn island
# City not found. Skipping...
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_wx_df = pd.DataFrame({
    'City':city_wx,
    'Lat':lat, 
    'Lng':lon,
    'Max Temp':maxTemp, 
    'Humidity':humidity, 
    'Cloudiness':cloudiness,
    'Wind Speed':windSpeed, 
    'Country':country, 
    'Date':date
})
city_wx_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    yellowknife  62.46 -114.35     18.00        92          75       10.29
# 1         narsaq  60.92  -46.05     21.20        53          40        3.36
# 2  leningradskiy  69.38  178.42      7.68        86          69        3.74
# 3        ushuaia -54.80  -68.30     50.00        76          75       13.87
# 4         castro -24.79  -50.01     66.31        93          76        5.44
#
#   Country        Date
# 0      CA  1607376601
# 1      GL  1607376586
# 2      RU  1607376820
# 3      AR  1607376491
# 4      BR  1607376571

# %%
city_wx_df.to_csv('../output_data/cities.csv')

# %%
filepath = '../output_data/cities.csv'
f = pd.read_csv(filepath)
df = pd.DataFrame(f)
df = df.drop(columns=['Unnamed: 0'])

df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    yellowknife  62.46 -114.35     18.00        92          75       10.29
# 1         narsaq  60.92  -46.05     21.20        53          40        3.36
# 2  leningradskiy  69.38  178.42      7.68        86          69        3.74
# 3        ushuaia -54.80  -68.30     50.00        76          75       13.87
# 4         castro -24.79  -50.01     66.31        93          76        5.44
#
#   Country        Date
# 0      CA  1607376601
# 1      GL  1607376586
# 2      RU  1607376820
# 3      AR  1607376491
# 4      BR  1607376571

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
print(df.loc[df['Humidity']>100,:])
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temp ({title_date})')
plt.tight_layout()


plt.savefig('../output_data/Fig1.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({title_date})')
plt.tight_layout()

plt.savefig('../output_data/Fig2.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloud Coverage ({title_date})')
plt.tight_layout()

plt.savefig('../output_data/Fig3.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({title_date})')
plt.tight_layout()

plt.savefig('../output_data/Fig4.png')

# %% [markdown]
# ## Linear Regression

# %%
northHem_df = df.loc[df['Lat']>=0,:]

# %%
northHem_df = df.loc[df['Lat']>=0,:]
x_value = northHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Max Temp'])
regress_value = x_value*slope + intercept

datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

northHem_df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Max Temp ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,-20), fontsize=15)
# Out:
# Text(0, -20, 'y = -1.25x + 91.24')

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southHem_df = df.loc[df['Lat']<=0,:]
x_value = southHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Max Temp'])
regress_value = x_value*slope + intercept

datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

southHem_df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Max Temp ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-30,50), fontsize=15)
# Out:
# Text(-30, 50, 'y = 0.29x + 78.64')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northHem_df = df.loc[df['Lat']>=0,:]
x_value = northHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Humidity'])
regress_value = x_value*slope + intercept

datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

northHem_df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Humidity ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,5), fontsize=15)
# Out:
# Text(0, 5, 'y = 0.36x + 60.33')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
southHem_df = df.loc[df['Lat']<=0,:]
x_value = southHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Humidity'])
regress_value = x_value*slope + intercept

datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

southHem_df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Humidity ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-25,30), fontsize=15)
# Out:
# Text(-25, 30, 'y = 0.57x + 84.8')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
northHem_df = df.loc[df['Lat']>=0,:]
x_value = northHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Cloudiness'])
regress_value = x_value*slope + intercept

datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

northHem_df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Cloud Coverage (%)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Cloud Coverage ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(45,20), fontsize=15)
# Out:
# Text(45, 20, 'y = 0.47x + 33.45')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
southHem_df = df.loc[df['Lat']<=0,:]
x_value = southHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Cloudiness'])
regress_value = x_value*slope + intercept

datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

southHem_df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Cloud Coverage (%)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Cloud Coverage ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-50,60), fontsize=15)
# Out:
# Text(-50, 60, 'y = 1.08x + 70.77')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
northHem_df = df.loc[df['Lat']>=0,:]
x_value = northHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Wind Speed'])
regress_value = x_value*slope + intercept

datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

northHem_df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Wind Speed ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,30), fontsize=15)
# Out:
# Text(0, 30, 'y = 0.03x + 6.56')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
southHem_df = df.loc[df['Lat']<=0,:]
x_value = southHem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Wind Speed'])
regress_value = x_value*slope + intercept

datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

southHem_df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Wind Speed ({title_date})')

line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-30,23), fontsize=15)
# Out:
# Text(-30, 23, 'y = -0.1x + 5.79')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

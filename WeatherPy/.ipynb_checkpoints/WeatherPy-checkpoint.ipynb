# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
#Building Query URL
query_url = f"{base_url}appid={weather_api_key}&q="

# %%
city_wx = []
lat = []
lon = []
maxTemp = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

record_count = 1
set_count = 1

print('Beginning Data Retrieval')
print('------------------------')
for city in cities:
    if record_count >= 50:
        time.sleep(60)
        record_count = 0
        set_count += 1
    
    response = requests.get(query_url + city + '&units=imperial').json()
    record_count += 1
    
    try:
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_wx.append(city)
        print(f'Processing Record {record_count} of Set {set_count} | {city}')
    except KeyError:
        print('City not found. Skipping...')
print('------------------------')
print('Data Retrieval Complete')
print('------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 1 | kidal
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | zaraza
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | montbrison
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | sao filipe
# Processing Record 22 of Set 1 | korla
# Processing Record 23 of Set 1 | duldurga
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | hami
# Processing Record 26 of Set 1 | leningradskiy
# Processing Record 27 of Set 1 | hastings
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | padang
# Processing Record 31 of Set 1 | chokurdakh
# Processing Record 32 of Set 1 | san patricio
# Processing Record 33 of Set 1 | emerald
# Processing Record 34 of Set 1 | karratha
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | quatre cocos
# Processing Record 38 of Set 1 | todos santos
# Processing Record 39 of Set 1 | natal
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | roma
# Processing Record 43 of Set 1 | meulaboh
# Processing Record 44 of Set 1 | vidim
# Processing Record 45 of Set 1 | machali
# Processing Record 46 of Set 1 | ramonville-saint-agne
# City not found. Skipping...
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | benguela
# Processing Record 50 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 2 of Set 2 | naze
# City not found. Skipping...
# Processing Record 4 of Set 2 | tayshet
# Processing Record 5 of Set 2 | masallatah
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | dustlik
# Processing Record 9 of Set 2 | veraval
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | isangel
# Processing Record 17 of Set 2 | saskylakh
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | mol
# Processing Record 21 of Set 2 | tomatlan
# Processing Record 22 of Set 2 | antonina
# Processing Record 23 of Set 2 | cockburn town
# Processing Record 24 of Set 2 | puri
# City not found. Skipping...
# Processing Record 26 of Set 2 | quixada
# Processing Record 27 of Set 2 | alyangula
# Processing Record 28 of Set 2 | tefe
# Processing Record 29 of Set 2 | kumi
# City not found. Skipping...
# Processing Record 31 of Set 2 | vieux-habitants
# Processing Record 32 of Set 2 | aswan
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | guerrero negro
# Processing Record 35 of Set 2 | port hedland
# City not found. Skipping...
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | el tarra
# Processing Record 39 of Set 2 | weligama
# Processing Record 40 of Set 2 | tasiilaq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | komsomolskiy
# Processing Record 47 of Set 2 | canico
# Processing Record 48 of Set 2 | diapaga
# Processing Record 49 of Set 2 | sayat
# Processing Record 50 of Set 2 | lasa
# Processing Record 1 of Set 3 | ust-kan
# City not found. Skipping...
# Processing Record 3 of Set 3 | lakatoro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 3 | bobrovka
# Processing Record 7 of Set 3 | cozumel
# Processing Record 8 of Set 3 | cranbrook
# Processing Record 9 of Set 3 | saint-georges
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | nakamura
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | cervo
# Processing Record 15 of Set 3 | khatima
# Processing Record 16 of Set 3 | chesma
# Processing Record 17 of Set 3 | mbini
# Processing Record 18 of Set 3 | usoke
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | tilichiki
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | mutuipe
# Processing Record 24 of Set 3 | vila
# Processing Record 25 of Set 3 | asau
# City not found. Skipping...
# Processing Record 27 of Set 3 | smirnykh
# Processing Record 28 of Set 3 | deer lake
# Processing Record 29 of Set 3 | barrow
# Processing Record 30 of Set 3 | baculin
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | buzmeyin
# Processing Record 34 of Set 3 | havelock
# City not found. Skipping...
# Processing Record 36 of Set 3 | salinopolis
# Processing Record 37 of Set 3 | maningrida
# Processing Record 38 of Set 3 | penzance
# Processing Record 39 of Set 3 | vaini
# City not found. Skipping...
# Processing Record 41 of Set 3 | ambilobe
# Processing Record 42 of Set 3 | moussoro
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | musoma
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | luwuk
# Processing Record 49 of Set 3 | vostok
# City not found. Skipping...
# Processing Record 1 of Set 4 | broome
# Processing Record 2 of Set 4 | novikovo
# Processing Record 3 of Set 4 | catamarca
# Processing Record 4 of Set 4 | george town
# Processing Record 5 of Set 4 | moree
# Processing Record 6 of Set 4 | hobart
# Processing Record 7 of Set 4 | avarua
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | honiara
# Processing Record 10 of Set 4 | inirida
# City not found. Skipping...
# Processing Record 12 of Set 4 | guapi
# Processing Record 13 of Set 4 | vestmannaeyjar
# Processing Record 14 of Set 4 | hermanus
# Processing Record 15 of Set 4 | anadyr
# Processing Record 16 of Set 4 | matay
# Processing Record 17 of Set 4 | moron
# Processing Record 18 of Set 4 | mumford
# Processing Record 19 of Set 4 | gladstone
# Processing Record 20 of Set 4 | iquique
# Processing Record 21 of Set 4 | souillac
# City not found. Skipping...
# Processing Record 23 of Set 4 | tuktoyaktuk
# Processing Record 24 of Set 4 | allapalli
# Processing Record 25 of Set 4 | tutoia
# Processing Record 26 of Set 4 | general roca
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | paramonga
# Processing Record 29 of Set 4 | butaritari
# Processing Record 30 of Set 4 | gwadar
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | grand gaube
# Processing Record 33 of Set 4 | riviere-au-renard
# Processing Record 34 of Set 4 | pimenta bueno
# Processing Record 35 of Set 4 | zhicheng
# Processing Record 36 of Set 4 | palmer
# Processing Record 37 of Set 4 | vila velha
# Processing Record 38 of Set 4 | atambua
# Processing Record 39 of Set 4 | preveza
# Processing Record 40 of Set 4 | jumla
# Processing Record 41 of Set 4 | shadegan
# Processing Record 42 of Set 4 | portland
# Processing Record 43 of Set 4 | fortuna
# Processing Record 44 of Set 4 | teguise
# Processing Record 45 of Set 4 | maceio
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | kruisfontein
# Processing Record 48 of Set 4 | fort nelson
# Processing Record 49 of Set 4 | meadow lake
# Processing Record 50 of Set 4 | pacific grove
# Processing Record 1 of Set 5 | kotlas
# Processing Record 2 of Set 5 | kieta
# Processing Record 3 of Set 5 | mizoch
# Processing Record 4 of Set 5 | bethel
# Processing Record 5 of Set 5 | victor harbor
# Processing Record 6 of Set 5 | kurumkan
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | mende
# Processing Record 10 of Set 5 | athabasca
# Processing Record 11 of Set 5 | byron bay
# Processing Record 12 of Set 5 | caninde
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | syava
# Processing Record 16 of Set 5 | roanoke rapids
# Processing Record 17 of Set 5 | mount gambier
# Processing Record 18 of Set 5 | sisimiut
# Processing Record 19 of Set 5 | ust-nera
# Processing Record 20 of Set 5 | hilo
# Processing Record 21 of Set 5 | saint-francois
# Processing Record 22 of Set 5 | kodiak
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | sao joao da barra
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | ostrovnoy
# Processing Record 27 of Set 5 | krasnoarmeysk
# Processing Record 28 of Set 5 | alugan
# Processing Record 29 of Set 5 | valparaiso
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | kautokeino
# Processing Record 32 of Set 5 | taywarah
# Processing Record 33 of Set 5 | yerbogachen
# Processing Record 34 of Set 5 | nesterov
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | ilyich
# Processing Record 37 of Set 5 | mehamn
# Processing Record 38 of Set 5 | tevaitoa
# Processing Record 39 of Set 5 | pangnirtung
# Processing Record 40 of Set 5 | kalabo
# Processing Record 41 of Set 5 | tando muhammad khan
# City not found. Skipping...
# Processing Record 43 of Set 5 | new norfolk
# Processing Record 44 of Set 5 | morant bay
# Processing Record 45 of Set 5 | tiznit
# Processing Record 46 of Set 5 | ormara
# City not found. Skipping...
# Processing Record 48 of Set 5 | mahebourg
# City not found. Skipping...
# Processing Record 50 of Set 5 | san nicolas
# Processing Record 1 of Set 6 | talnakh
# City not found. Skipping...
# Processing Record 3 of Set 6 | labuhan
# Processing Record 4 of Set 6 | mae hong son
# Processing Record 5 of Set 6 | dakar
# Processing Record 6 of Set 6 | mocuba
# Processing Record 7 of Set 6 | bonnyville
# Processing Record 8 of Set 6 | verkhoshizhemye
# City not found. Skipping...
# Processing Record 10 of Set 6 | lohja
# Processing Record 11 of Set 6 | namtsy
# Processing Record 12 of Set 6 | pirapozinho
# Processing Record 13 of Set 6 | ribeira grande
# Processing Record 14 of Set 6 | zheleznodorozhnyy
# Processing Record 15 of Set 6 | puerto colombia
# Processing Record 16 of Set 6 | great yarmouth
# Processing Record 17 of Set 6 | vao
# Processing Record 18 of Set 6 | cordoba
# Processing Record 19 of Set 6 | manono
# City not found. Skipping...
# Processing Record 21 of Set 6 | impfondo
# Processing Record 22 of Set 6 | andenes
# Processing Record 23 of Set 6 | homestead
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 6 | torbay
# Processing Record 27 of Set 6 | luanda
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | rio gallegos
# Processing Record 30 of Set 6 | walvis bay
# Processing Record 31 of Set 6 | asyut
# Processing Record 32 of Set 6 | vizinga
# City not found. Skipping...
# Processing Record 34 of Set 6 | nur
# City not found. Skipping...
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | acari
# Processing Record 38 of Set 6 | beyneu
# Processing Record 39 of Set 6 | ziarat
# Processing Record 40 of Set 6 | vila do maio
# Processing Record 41 of Set 6 | san cristobal
# Processing Record 42 of Set 6 | port hardy
# Processing Record 43 of Set 6 | pervomayskiy
# Processing Record 44 of Set 6 | bengkulu
# Processing Record 45 of Set 6 | port lincoln
# Processing Record 46 of Set 6 | katangli
# Processing Record 47 of Set 6 | hokitika
# Processing Record 48 of Set 6 | walbrzych
# Processing Record 49 of Set 6 | saint george
# Processing Record 50 of Set 6 | turayf
# Processing Record 1 of Set 7 | beringovskiy
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | hohhot
# Processing Record 4 of Set 7 | cahabon
# Processing Record 5 of Set 7 | samarai
# Processing Record 6 of Set 7 | viedma
# Processing Record 7 of Set 7 | atakpame
# Processing Record 8 of Set 7 | formosa
# City not found. Skipping...
# Processing Record 10 of Set 7 | athens
# Processing Record 11 of Set 7 | muborak
# Processing Record 12 of Set 7 | mar del plata
# Processing Record 13 of Set 7 | yar-sale
# Processing Record 14 of Set 7 | madisonville
# Processing Record 15 of Set 7 | imbituba
# Processing Record 16 of Set 7 | nuuk
# Processing Record 17 of Set 7 | matara
# City not found. Skipping...
# Processing Record 19 of Set 7 | nadym
# Processing Record 20 of Set 7 | mujiayingzi
# Processing Record 21 of Set 7 | trelew
# Processing Record 22 of Set 7 | olinda
# Processing Record 23 of Set 7 | gouyave
# Processing Record 24 of Set 7 | namibe
# Processing Record 25 of Set 7 | nome
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | hasaki
# Processing Record 28 of Set 7 | tura
# Processing Record 29 of Set 7 | sabang
# Processing Record 30 of Set 7 | porto seguro
# Processing Record 31 of Set 7 | abu dhabi
# Processing Record 32 of Set 7 | yulara
# Processing Record 33 of Set 7 | moindou
# Processing Record 34 of Set 7 | cabedelo
# Processing Record 35 of Set 7 | san isidro
# City not found. Skipping...
# Processing Record 37 of Set 7 | santa cruz
# Processing Record 38 of Set 7 | maraba
# Processing Record 39 of Set 7 | manjeshwar
# Processing Record 40 of Set 7 | kroya
# Processing Record 41 of Set 7 | shimoda
# City not found. Skipping...
# Processing Record 43 of Set 7 | juquitiba
# Processing Record 44 of Set 7 | sechura
# Processing Record 45 of Set 7 | mabaruma
# City not found. Skipping...
# Processing Record 47 of Set 7 | krasnoselkup
# Processing Record 48 of Set 7 | yendi
# Processing Record 49 of Set 7 | teresopolis
# Processing Record 50 of Set 7 | khatanga
# City not found. Skipping...
# Processing Record 2 of Set 8 | borda da mata
# Processing Record 3 of Set 8 | oranjemund
# Processing Record 4 of Set 8 | klyuchi
# Processing Record 5 of Set 8 | cotofanesti
# Processing Record 6 of Set 8 | najran
# Processing Record 7 of Set 8 | sao gabriel da cachoeira
# Processing Record 8 of Set 8 | mongo
# Processing Record 9 of Set 8 | bolshoye murashkino
# Processing Record 10 of Set 8 | da lat
# City not found. Skipping...
# Processing Record 12 of Set 8 | hervey bay
# Processing Record 13 of Set 8 | arraial do cabo
# Processing Record 14 of Set 8 | san rafael
# Processing Record 15 of Set 8 | zhigansk
# Processing Record 16 of Set 8 | dosso
# Processing Record 17 of Set 8 | luba
# City not found. Skipping...
# Processing Record 19 of Set 8 | ancud
# Processing Record 20 of Set 8 | gat
# Processing Record 21 of Set 8 | mattawa
# Processing Record 22 of Set 8 | the valley
# Processing Record 23 of Set 8 | ponferrada
# Processing Record 24 of Set 8 | severo-kurilsk
# Processing Record 25 of Set 8 | rocha
# Processing Record 26 of Set 8 | kahului
# Processing Record 27 of Set 8 | san juan
# Processing Record 28 of Set 8 | ukiah
# Processing Record 29 of Set 8 | masuguru
# Processing Record 30 of Set 8 | fairbanks
# Processing Record 31 of Set 8 | kirakira
# Processing Record 32 of Set 8 | vanderhoof
# Processing Record 33 of Set 8 | auki
# Processing Record 34 of Set 8 | yumen
# Processing Record 35 of Set 8 | logon
# Processing Record 36 of Set 8 | conroe
# Processing Record 37 of Set 8 | esperance
# Processing Record 38 of Set 8 | taoudenni
# Processing Record 39 of Set 8 | kununurra
# Processing Record 40 of Set 8 | hermon
# Processing Record 41 of Set 8 | maniitsoq
# City not found. Skipping...
# Processing Record 43 of Set 8 | smithers
# Processing Record 44 of Set 8 | sangar
# Processing Record 45 of Set 8 | bubaque
# Processing Record 46 of Set 8 | lavrentiya
# Processing Record 47 of Set 8 | waipawa
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | nuzvid
# Processing Record 50 of Set 8 | saint-augustin
# City not found. Skipping...
# Processing Record 2 of Set 9 | buin
# Processing Record 3 of Set 9 | caohe
# Processing Record 4 of Set 9 | aktau
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | beroroha
# Processing Record 7 of Set 9 | nizhniy bestyakh
# Processing Record 8 of Set 9 | harwich
# Processing Record 9 of Set 9 | pueblo
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | sri aman
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 9 | kavaratti
# Processing Record 15 of Set 9 | gamba
# Processing Record 16 of Set 9 | verkhnevilyuysk
# Processing Record 17 of Set 9 | coquimbo
# Processing Record 18 of Set 9 | sept-iles
# Processing Record 19 of Set 9 | virginia beach
# Processing Record 20 of Set 9 | hualmay
# Processing Record 21 of Set 9 | emba
# Processing Record 22 of Set 9 | chimoio
# Processing Record 23 of Set 9 | merauke
# Processing Record 24 of Set 9 | biltine
# Processing Record 25 of Set 9 | cayenne
# Processing Record 26 of Set 9 | mangrol
# Processing Record 27 of Set 9 | gazojak
# Processing Record 28 of Set 9 | akropong
# City not found. Skipping...
# Processing Record 30 of Set 9 | rapid valley
# Processing Record 31 of Set 9 | zaysan
# Processing Record 32 of Set 9 | sekoma
# Processing Record 33 of Set 9 | ponta delgada
# Processing Record 34 of Set 9 | rocky mountain house
# Processing Record 35 of Set 9 | mandalgovi
# Processing Record 36 of Set 9 | bullhead city
# Processing Record 37 of Set 9 | regina
# Processing Record 38 of Set 9 | sorland
# Processing Record 39 of Set 9 | barra do garcas
# Processing Record 40 of Set 9 | margate
# Processing Record 41 of Set 9 | shitanjing
# City not found. Skipping...
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | reyes
# Processing Record 45 of Set 9 | otane
# Processing Record 46 of Set 9 | richards bay
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | alice springs
# Processing Record 49 of Set 9 | korkmaskala
# City not found. Skipping...
# Processing Record 1 of Set 10 | panhala
# Processing Record 2 of Set 10 | ninghai
# Processing Record 3 of Set 10 | leshukonskoye
# City not found. Skipping...
# Processing Record 5 of Set 10 | znamenskoye
# Processing Record 6 of Set 10 | piracanjuba
# City not found. Skipping...
# Processing Record 8 of Set 10 | kaeo
# Processing Record 9 of Set 10 | palmerston
# City not found. Skipping...
# Processing Record 11 of Set 10 | belyy yar
# Processing Record 12 of Set 10 | batemans bay
# Processing Record 13 of Set 10 | mahenge
# Processing Record 14 of Set 10 | havoysund
# Processing Record 15 of Set 10 | lakheri
# Processing Record 16 of Set 10 | puerto leguizamo
# Processing Record 17 of Set 10 | kimbe
# Processing Record 18 of Set 10 | cherskiy
# Processing Record 19 of Set 10 | rumuruti
# Processing Record 20 of Set 10 | ilebo
# City not found. Skipping...
# Processing Record 22 of Set 10 | bambanglipuro
# Processing Record 23 of Set 10 | zhuhai
# Processing Record 24 of Set 10 | pedasi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 10 | itoman
# Processing Record 28 of Set 10 | nouakchott
# Processing Record 29 of Set 10 | dongsheng
# Processing Record 30 of Set 10 | minab
# Processing Record 31 of Set 10 | arroyo
# Processing Record 32 of Set 10 | requena
# Processing Record 33 of Set 10 | sapa
# Processing Record 34 of Set 10 | nagapattinam
# Processing Record 35 of Set 10 | marsa matruh
# Processing Record 36 of Set 10 | laishevo
# Processing Record 37 of Set 10 | husavik
# Processing Record 38 of Set 10 | abu samrah
# Processing Record 39 of Set 10 | pangkalanbuun
# Processing Record 40 of Set 10 | asha
# Processing Record 41 of Set 10 | pipri
# Processing Record 42 of Set 10 | coahuayana
# Processing Record 43 of Set 10 | flinders
# Processing Record 44 of Set 10 | chilca
# Processing Record 45 of Set 10 | alofi
# Processing Record 46 of Set 10 | santa vitoria do palmar
# Processing Record 47 of Set 10 | nyeri
# Processing Record 48 of Set 10 | ampanihy
# Processing Record 49 of Set 10 | plock
# Processing Record 50 of Set 10 | ashington
# Processing Record 1 of Set 11 | risalpur
# Processing Record 2 of Set 11 | terrace bay
# Processing Record 3 of Set 11 | christchurch
# Processing Record 4 of Set 11 | illapel
# Processing Record 5 of Set 11 | tumen
# Processing Record 6 of Set 11 | polunochnoye
# Processing Record 7 of Set 11 | acarau
# Processing Record 8 of Set 11 | simbahan
# Processing Record 9 of Set 11 | sola
# Processing Record 10 of Set 11 | cananeia
# Processing Record 11 of Set 11 | danjiangkou
# Processing Record 12 of Set 11 | bangangte
# Processing Record 13 of Set 11 | te anau
# City not found. Skipping...
# Processing Record 15 of Set 11 | hearst
# Processing Record 16 of Set 11 | lagoa
# Processing Record 17 of Set 11 | pahrump
# Processing Record 18 of Set 11 | ugoofaaru
# Processing Record 19 of Set 11 | nioaque
# Processing Record 20 of Set 11 | la plata
# Processing Record 21 of Set 11 | kathmandu
# Processing Record 22 of Set 11 | ust-maya
# City not found. Skipping...
# Processing Record 24 of Set 11 | touros
# Processing Record 25 of Set 11 | eyl
# Processing Record 26 of Set 11 | reforma
# Processing Record 27 of Set 11 | latur
# Processing Record 28 of Set 11 | doume
# Processing Record 29 of Set 11 | sokoni
# Processing Record 30 of Set 11 | prince george
# Processing Record 31 of Set 11 | kushima
# Processing Record 32 of Set 11 | bukama
# Processing Record 33 of Set 11 | lerwick
# Processing Record 34 of Set 11 | tlaxco
# Processing Record 35 of Set 11 | craig
# Processing Record 36 of Set 11 | tuensang
# Processing Record 37 of Set 11 | etchoropo
# Processing Record 38 of Set 11 | eureka
# Processing Record 39 of Set 11 | jurado
# Processing Record 40 of Set 11 | makasar
# Processing Record 41 of Set 11 | muisne
# Processing Record 42 of Set 11 | agadez
# Processing Record 43 of Set 11 | wakefield
# Processing Record 44 of Set 11 | tonantins
# Processing Record 45 of Set 11 | polyarnyy
# Processing Record 46 of Set 11 | udachnyy
# Processing Record 47 of Set 11 | marawi
# Processing Record 48 of Set 11 | kruje
# Processing Record 49 of Set 11 | aklavik
# Processing Record 50 of Set 11 | abaza
# Processing Record 1 of Set 12 | hammelburg
# Processing Record 2 of Set 12 | senador guiomard
# Processing Record 3 of Set 12 | hamilton
# Processing Record 4 of Set 12 | shache
# Processing Record 5 of Set 12 | varia
# Processing Record 6 of Set 12 | meybod
# Processing Record 7 of Set 12 | landeck
# City not found. Skipping...
# Processing Record 9 of Set 12 | burnie
# Processing Record 10 of Set 12 | trimbak
# Processing Record 11 of Set 12 | oriximina
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | ginda
# Processing Record 14 of Set 12 | taksimo
# Processing Record 15 of Set 12 | boditi
# City not found. Skipping...
# Processing Record 17 of Set 12 | mont-dore
# Processing Record 18 of Set 12 | marsh harbour
# Processing Record 19 of Set 12 | kallithea
# Processing Record 20 of Set 12 | sakakah
# City not found. Skipping...
# Processing Record 22 of Set 12 | bairiki
# Processing Record 23 of Set 12 | birao
# Processing Record 24 of Set 12 | wencheng
# Processing Record 25 of Set 12 | buala
# Processing Record 26 of Set 12 | kudahuvadhoo
# Processing Record 27 of Set 12 | kamenka
# Processing Record 28 of Set 12 | ilhabela
# Processing Record 29 of Set 12 | petropavlovka
# Processing Record 30 of Set 12 | khandyga
# Processing Record 31 of Set 12 | half moon bay
# Processing Record 32 of Set 12 | zhizdra
# Processing Record 33 of Set 12 | caravelas
# Processing Record 34 of Set 12 | belmonte
# Processing Record 35 of Set 12 | altea
# Processing Record 36 of Set 12 | bardstown
# Processing Record 37 of Set 12 | henties bay
# Processing Record 38 of Set 12 | lardos
# Processing Record 39 of Set 12 | cap malheureux
# Processing Record 40 of Set 12 | eusebio ayala
# Processing Record 41 of Set 12 | gisborne
# Processing Record 42 of Set 12 | ketchikan
# Processing Record 43 of Set 12 | evensk
# Processing Record 44 of Set 12 | aksu
# Processing Record 45 of Set 12 | college
# Processing Record 46 of Set 12 | palestina
# Processing Record 47 of Set 12 | berdigestyakh
# Processing Record 48 of Set 12 | buraydah
# Processing Record 49 of Set 12 | domoni
# Processing Record 50 of Set 12 | puerto ayacucho
# Processing Record 1 of Set 13 | georgiyevskoye
# Processing Record 2 of Set 13 | mount isa
# Processing Record 3 of Set 13 | gornopravdinsk
# Processing Record 4 of Set 13 | itarema
# Processing Record 5 of Set 13 | lucapa
# Processing Record 6 of Set 13 | havre-saint-pierre
# Processing Record 7 of Set 13 | sungaipenuh
# Processing Record 8 of Set 13 | shu
# Processing Record 9 of Set 13 | avera
# Processing Record 10 of Set 13 | port macquarie
# Processing Record 11 of Set 13 | calvinia
# Processing Record 12 of Set 13 | formosa do rio preto
# City not found. Skipping...
# Processing Record 14 of Set 13 | lampitak
# Processing Record 15 of Set 13 | phan thiet
# Processing Record 16 of Set 13 | san andres
# Processing Record 17 of Set 13 | bonavista
# Processing Record 18 of Set 13 | sorong
# Processing Record 19 of Set 13 | chernyshevskiy
# Processing Record 20 of Set 13 | sovetskiy
# Processing Record 21 of Set 13 | soyo
# Processing Record 22 of Set 13 | tessalit
# Processing Record 23 of Set 13 | mantua
# Processing Record 24 of Set 13 | sur
# Processing Record 25 of Set 13 | tera
# Processing Record 26 of Set 13 | tahta
# Processing Record 27 of Set 13 | nelson bay
# Processing Record 28 of Set 13 | hofn
# Processing Record 29 of Set 13 | bandarbeyla
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_wx_df = pd.DataFrame({
    'City':city_wx,
    'Lat':lat, 
    'Lng':lon,
    'Max Temp':maxTemp, 
    'Humidity':humidity, 
    'Cloudiness':cloudiness,
    'Wind Speed':windSpeed, 
    'Country':country, 
    'Date':date
})
city_wx_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-113c9fad106f> in <module>
#       1 city_wx_df = pd.DataFrame({
# ----> 2     'City':city_wx,
#       3     'Lat':lat,
#       4     'Lng':lon,
#       5     'Max Temp':maxTemp,
#
# NameError: name 'city_wx' is not defined

# %%
city_wx_df.to_csv('../output_data/cities.csv')

# %%
filepath = '../output_data/cities.csv'
f = pd.read_csv(filepath)
df = pd.DataFrame(f)
df = df.drop(columns=['Unnamed: 0'])

df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  punta arenas -53.15  -70.92     60.80        59         100       25.28
# 1        atuona  -9.80 -139.03     78.46        74           1       15.03
# 2         kapaa  22.08 -159.32     84.20        66          40       10.29
# 3       ushuaia -54.80  -68.30     50.00        93          75        2.68
# 4       rikitea -23.12 -134.97     76.89        78           7       14.52
#
#   Country        Date
# 0      CL  1607298269
# 1      PF  1607298260
# 2      US  1607298267
# 3      AR  1607298201
# 4      PF  1607298269

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
print(df.loc[df['Humidity']>100,:])
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
datestamp = time.gmtime(1607298269)
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude of vs Max Temp ({title_date})')
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
datestamp = time.gmtime(1607298269)
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude of vs Humidity ({title_date})')
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
datestamp = time.gmtime(1607298269)
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude of vs Cloud Coverage ({title_date})')
plt.tight_layout()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
datestamp = time.gmtime(1607298269)
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude of vs Wind Speed ({title_date})')
plt.tight_layout()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

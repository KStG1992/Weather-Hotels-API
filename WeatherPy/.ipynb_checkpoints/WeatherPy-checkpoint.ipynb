# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 651

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
#Building Query URL
query_url = f"{base_url}appid={weather_api_key}&q="

# %%
# Creating Empty Lists
city_wx = []
lat = []
lon = []
maxTemp = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

# Using a For Loop to Make Successive API Calls
record_count = 1
set_count = 1

print('Beginning Data Retrieval')
print('------------------------')

# Loop Through Each City
# OpenWeather API will Allow 60 Calls/Min
# The Counter and .sleep Method will Us to Freely Call Data
for city in cities:
    if record_count >= 50:
        time.sleep(60)
        record_count = 0
        set_count += 1

    # Making Requests        
    response = requests.get(query_url + city + '&units=imperial').json()
    record_count += 1
   
    # Using Try/Except to Grab Variables if Available
    try:
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_wx.append(city)
        print(f'Processing Record {record_count} of Set {set_count} | {city}')
    except KeyError:
        print('City not found. Skipping...')
print('------------------------')
print('Data Retrieval Complete')
print('------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 2 of Set 1 | aksu
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | neiafu
# Processing Record 5 of Set 1 | sobolevo
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | itaituba
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | carnarvon
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 1 | isangel
# City not found. Skipping...
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | astana
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | cafelandia
# Processing Record 23 of Set 1 | santa maria
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | daoukro
# Processing Record 26 of Set 1 | grindavik
# Processing Record 27 of Set 1 | danielskuil
# City not found. Skipping...
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | okhotsk
# Processing Record 31 of Set 1 | cross lanes
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | sturgis
# Processing Record 34 of Set 1 | bekhtery
# City not found. Skipping...
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | leon
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | mehamn
# Processing Record 40 of Set 1 | udachnyy
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | anadyr
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | taganak
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | pontianak
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | chalmette
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | nanzhang
# Processing Record 6 of Set 2 | baruun-urt
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | douentza
# Processing Record 10 of Set 2 | kapaa
# City not found. Skipping...
# Processing Record 12 of Set 2 | duvan
# City not found. Skipping...
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | tshela
# City not found. Skipping...
# Processing Record 18 of Set 2 | naze
# Processing Record 19 of Set 2 | jalapa
# Processing Record 20 of Set 2 | aktau
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | bubaque
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | zeya
# Processing Record 26 of Set 2 | qui nhon
# Processing Record 27 of Set 2 | sept-iles
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | yerbogachen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | gao
# Processing Record 40 of Set 2 | henties bay
# Processing Record 41 of Set 2 | tautira
# Processing Record 42 of Set 2 | port hardy
# Processing Record 43 of Set 2 | tarnobrzeg
# Processing Record 44 of Set 2 | chapais
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | pathein
# Processing Record 47 of Set 2 | carutapera
# Processing Record 48 of Set 2 | wanning
# Processing Record 49 of Set 2 | palmer
# Processing Record 50 of Set 2 | glendive
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | yeppoon
# Processing Record 4 of Set 3 | kindu
# Processing Record 5 of Set 3 | chumikan
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | anori
# City not found. Skipping...
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | aitape
# Processing Record 11 of Set 3 | robore
# Processing Record 12 of Set 3 | nelson bay
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | bayji
# Processing Record 16 of Set 3 | gerede
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | manado
# Processing Record 19 of Set 3 | alice springs
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | atuona
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | yar-sale
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | atar
# City not found. Skipping...
# Processing Record 28 of Set 3 | celestun
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | souillac
# Processing Record 31 of Set 3 | kahului
# Processing Record 32 of Set 3 | kalmunai
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | shalakusha
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | ulladulla
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | jurm
# Processing Record 40 of Set 3 | mount isa
# Processing Record 41 of Set 3 | bambous virieux
# City not found. Skipping...
# Processing Record 43 of Set 3 | kifri
# Processing Record 44 of Set 3 | adrar
# City not found. Skipping...
# Processing Record 46 of Set 3 | stolin
# City not found. Skipping...
# Processing Record 48 of Set 3 | san rafael
# Processing Record 49 of Set 3 | gewane
# Processing Record 50 of Set 3 | pisco
# Processing Record 1 of Set 4 | coracao de jesus
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | ust-maya
# Processing Record 4 of Set 4 | yulara
# Processing Record 5 of Set 4 | pemalang
# City not found. Skipping...
# Processing Record 7 of Set 4 | namatanai
# Processing Record 8 of Set 4 | verkhoyansk
# Processing Record 9 of Set 4 | uglegorsk
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | bredasdorp
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 4 | de-kastri
# Processing Record 15 of Set 4 | craig
# Processing Record 16 of Set 4 | san patricio
# City not found. Skipping...
# Processing Record 18 of Set 4 | san vicente
# Processing Record 19 of Set 4 | cajati
# Processing Record 20 of Set 4 | japura
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | penzance
# City not found. Skipping...
# Processing Record 24 of Set 4 | ormond beach
# Processing Record 25 of Set 4 | lata
# City not found. Skipping...
# Processing Record 27 of Set 4 | cacoal
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | sharlyk
# Processing Record 30 of Set 4 | houma
# City not found. Skipping...
# Processing Record 32 of Set 4 | flinders
# Processing Record 33 of Set 4 | yamada
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | katangli
# Processing Record 36 of Set 4 | yerofey pavlovich
# Processing Record 37 of Set 4 | yantzaza
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | maymyo
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | kupang
# Processing Record 42 of Set 4 | peniche
# Processing Record 43 of Set 4 | heihe
# Processing Record 44 of Set 4 | katobu
# Processing Record 45 of Set 4 | krasnogorskoye
# Processing Record 46 of Set 4 | kaura namoda
# Processing Record 47 of Set 4 | morondava
# Processing Record 48 of Set 4 | georgetown
# Processing Record 49 of Set 4 | castelo do piaui
# Processing Record 50 of Set 4 | jardim
# Processing Record 1 of Set 5 | gilbues
# Processing Record 2 of Set 5 | urumqi
# Processing Record 3 of Set 5 | dudinka
# Processing Record 4 of Set 5 | menongue
# Processing Record 5 of Set 5 | bagdarin
# Processing Record 6 of Set 5 | contamana
# Processing Record 7 of Set 5 | ponta do sol
# Processing Record 8 of Set 5 | catuday
# Processing Record 9 of Set 5 | general pico
# Processing Record 10 of Set 5 | shaowu
# Processing Record 11 of Set 5 | safford
# City not found. Skipping...
# Processing Record 13 of Set 5 | tezu
# Processing Record 14 of Set 5 | lumphat
# Processing Record 15 of Set 5 | ipameri
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | lichinga
# Processing Record 18 of Set 5 | nangong
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | delijan
# Processing Record 21 of Set 5 | kedrovyy
# Processing Record 22 of Set 5 | bathsheba
# Processing Record 23 of Set 5 | hinton
# Processing Record 24 of Set 5 | avera
# Processing Record 25 of Set 5 | rawson
# Processing Record 26 of Set 5 | nioro
# Processing Record 27 of Set 5 | pangkalanbuun
# Processing Record 28 of Set 5 | warrnambool
# Processing Record 29 of Set 5 | glyadyanskoye
# Processing Record 30 of Set 5 | hanzhong
# Processing Record 31 of Set 5 | port lincoln
# Processing Record 32 of Set 5 | lompoc
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | nemuro
# Processing Record 35 of Set 5 | oksovskiy
# Processing Record 36 of Set 5 | tashtyp
# Processing Record 37 of Set 5 | okakarara
# Processing Record 38 of Set 5 | juneau
# City not found. Skipping...
# Processing Record 40 of Set 5 | hay river
# Processing Record 41 of Set 5 | itarema
# Processing Record 42 of Set 5 | mar del plata
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | mazyr
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | cherskiy
# Processing Record 47 of Set 5 | bowen
# Processing Record 48 of Set 5 | olafsvik
# Processing Record 49 of Set 5 | grootfontein
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | broome
# Processing Record 2 of Set 6 | churapcha
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | alyangula
# Processing Record 5 of Set 6 | general roca
# Processing Record 6 of Set 6 | plettenberg bay
# Processing Record 7 of Set 6 | bull savanna
# Processing Record 8 of Set 6 | damietta
# City not found. Skipping...
# Processing Record 10 of Set 6 | erenhot
# Processing Record 11 of Set 6 | oroshaza
# Processing Record 12 of Set 6 | codrington
# Processing Record 13 of Set 6 | mizdah
# Processing Record 14 of Set 6 | altay
# Processing Record 15 of Set 6 | prince rupert
# City not found. Skipping...
# Processing Record 17 of Set 6 | grantham
# Processing Record 18 of Set 6 | ust-nera
# Processing Record 19 of Set 6 | lebu
# Processing Record 20 of Set 6 | padang
# Processing Record 21 of Set 6 | hibbing
# Processing Record 22 of Set 6 | sabile
# Processing Record 23 of Set 6 | cabedelo
# Processing Record 24 of Set 6 | kelvington
# Processing Record 25 of Set 6 | husavik
# Processing Record 26 of Set 6 | mandal
# Processing Record 27 of Set 6 | surt
# Processing Record 28 of Set 6 | shatrovo
# Processing Record 29 of Set 6 | vao
# Processing Record 30 of Set 6 | thompson
# Processing Record 31 of Set 6 | acapulco
# Processing Record 32 of Set 6 | chanika
# Processing Record 33 of Set 6 | redcar
# Processing Record 34 of Set 6 | hofn
# Processing Record 35 of Set 6 | chernaya kholunitsa
# Processing Record 36 of Set 6 | manavalakurichi
# Processing Record 37 of Set 6 | shelburne
# Processing Record 38 of Set 6 | gemena
# Processing Record 39 of Set 6 | camana
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | tasiilaq
# Processing Record 42 of Set 6 | marsa matruh
# Processing Record 43 of Set 6 | laguna
# Processing Record 44 of Set 6 | vesoul
# Processing Record 45 of Set 6 | canutama
# Processing Record 46 of Set 6 | aranos
# Processing Record 47 of Set 6 | dakar
# Processing Record 48 of Set 6 | kosonsoy
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | srednekolymsk
# Processing Record 1 of Set 7 | klaksvik
# City not found. Skipping...
# Processing Record 3 of Set 7 | portland
# Processing Record 4 of Set 7 | bay roberts
# Processing Record 5 of Set 7 | kuching
# Processing Record 6 of Set 7 | bud
# Processing Record 7 of Set 7 | tuatapere
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | baherden
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | waynesboro
# Processing Record 15 of Set 7 | nambucca heads
# Processing Record 16 of Set 7 | moose factory
# City not found. Skipping...
# Processing Record 18 of Set 7 | khor
# Processing Record 19 of Set 7 | tottori
# Processing Record 20 of Set 7 | kurdzhinovo
# Processing Record 21 of Set 7 | duluth
# Processing Record 22 of Set 7 | batagay
# City not found. Skipping...
# Processing Record 24 of Set 7 | richards bay
# Processing Record 25 of Set 7 | beeville
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | mengyin
# Processing Record 28 of Set 7 | vaasa
# Processing Record 29 of Set 7 | vieux-habitants
# Processing Record 30 of Set 7 | ambur
# Processing Record 31 of Set 7 | saint-augustin
# City not found. Skipping...
# Processing Record 33 of Set 7 | sao miguel do iguacu
# Processing Record 34 of Set 7 | gat
# Processing Record 35 of Set 7 | ratnagiri
# Processing Record 36 of Set 7 | sao joao da barra
# Processing Record 37 of Set 7 | mogadishu
# Processing Record 38 of Set 7 | sambava
# Processing Record 39 of Set 7 | gambela
# Processing Record 40 of Set 7 | praia da vitoria
# Processing Record 41 of Set 7 | lima
# Processing Record 42 of Set 7 | ilulissat
# Processing Record 43 of Set 7 | ormara
# Processing Record 44 of Set 7 | bedele
# Processing Record 45 of Set 7 | zhezkazgan
# Processing Record 46 of Set 7 | champasak
# Processing Record 47 of Set 7 | sao jose da coroa grande
# Processing Record 48 of Set 7 | bonavista
# Processing Record 49 of Set 7 | inhambane
# Processing Record 50 of Set 7 | trincomalee
# Processing Record 1 of Set 8 | sidi ali
# Processing Record 2 of Set 8 | iracoubo
# Processing Record 3 of Set 8 | pacific grove
# Processing Record 4 of Set 8 | witu
# Processing Record 5 of Set 8 | carahue
# Processing Record 6 of Set 8 | hovd
# Processing Record 7 of Set 8 | vila
# Processing Record 8 of Set 8 | elbistan
# Processing Record 9 of Set 8 | biggar
# Processing Record 10 of Set 8 | aksarka
# Processing Record 11 of Set 8 | belaya gora
# City not found. Skipping...
# Processing Record 13 of Set 8 | kudahuvadhoo
# Processing Record 14 of Set 8 | kodiak
# City not found. Skipping...
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | sovetskiy
# Processing Record 18 of Set 8 | loandjili
# Processing Record 19 of Set 8 | puerto cabello
# Processing Record 20 of Set 8 | jacareacanga
# City not found. Skipping...
# Processing Record 22 of Set 8 | bandarbeyla
# Processing Record 23 of Set 8 | guadalupe y calvo
# Processing Record 24 of Set 8 | liwale
# Processing Record 25 of Set 8 | longyearbyen
# Processing Record 26 of Set 8 | nanortalik
# City not found. Skipping...
# Processing Record 28 of Set 8 | amsterdam
# City not found. Skipping...
# Processing Record 30 of Set 8 | moissala
# Processing Record 31 of Set 8 | beyla
# Processing Record 32 of Set 8 | kutum
# Processing Record 33 of Set 8 | blind river
# Processing Record 34 of Set 8 | praia
# Processing Record 35 of Set 8 | tabou
# Processing Record 36 of Set 8 | northam
# Processing Record 37 of Set 8 | adony
# Processing Record 38 of Set 8 | katyuzhanka
# Processing Record 39 of Set 8 | college
# Processing Record 40 of Set 8 | katsuura
# Processing Record 41 of Set 8 | severnyy
# City not found. Skipping...
# Processing Record 43 of Set 8 | gisborne
# Processing Record 44 of Set 8 | narsimhapur
# Processing Record 45 of Set 8 | mayo
# City not found. Skipping...
# Processing Record 47 of Set 8 | burley
# Processing Record 48 of Set 8 | athabasca
# Processing Record 49 of Set 8 | zambezi
# Processing Record 50 of Set 8 | nishihara
# Processing Record 1 of Set 9 | baculin
# City not found. Skipping...
# Processing Record 3 of Set 9 | gondanglegi
# Processing Record 4 of Set 9 | denpasar
# Processing Record 5 of Set 9 | nyimba
# Processing Record 6 of Set 9 | kiunga
# Processing Record 7 of Set 9 | borova
# City not found. Skipping...
# Processing Record 9 of Set 9 | gizo
# Processing Record 10 of Set 9 | kieta
# Processing Record 11 of Set 9 | nipawin
# Processing Record 12 of Set 9 | mucurapo
# Processing Record 13 of Set 9 | mango
# Processing Record 14 of Set 9 | eyl
# Processing Record 15 of Set 9 | brokopondo
# Processing Record 16 of Set 9 | riyadh
# Processing Record 17 of Set 9 | leningradskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | laureles
# Processing Record 20 of Set 9 | baft
# Processing Record 21 of Set 9 | la paz
# Processing Record 22 of Set 9 | san fernando
# Processing Record 23 of Set 9 | sarangani
# Processing Record 24 of Set 9 | belmonte
# Processing Record 25 of Set 9 | kericho
# Processing Record 26 of Set 9 | half moon bay
# Processing Record 27 of Set 9 | samur
# Processing Record 28 of Set 9 | nizwa
# Processing Record 29 of Set 9 | arima
# Processing Record 30 of Set 9 | buritis
# Processing Record 31 of Set 9 | shu
# Processing Record 32 of Set 9 | los llanos de aridane
# Processing Record 33 of Set 9 | zhangye
# Processing Record 34 of Set 9 | iqaluit
# Processing Record 35 of Set 9 | guerrero negro
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | aklavik
# Processing Record 38 of Set 9 | saint-paul
# Processing Record 39 of Set 9 | cinco esquinas
# Processing Record 40 of Set 9 | muscat
# Processing Record 41 of Set 9 | balaipungut
# Processing Record 42 of Set 9 | san cristobal
# Processing Record 43 of Set 9 | starkville
# Processing Record 44 of Set 9 | mackenzie
# Processing Record 45 of Set 9 | pangnirtung
# Processing Record 46 of Set 9 | merauke
# Processing Record 47 of Set 9 | sume
# Processing Record 48 of Set 9 | omboue
# Processing Record 49 of Set 9 | fortuna
# City not found. Skipping...
# Processing Record 1 of Set 10 | winnemucca
# Processing Record 2 of Set 10 | talaya
# Processing Record 3 of Set 10 | arrigorriaga
# Processing Record 4 of Set 10 | mae chan
# Processing Record 5 of Set 10 | genhe
# Processing Record 6 of Set 10 | usevya
# Processing Record 7 of Set 10 | talnakh
# Processing Record 8 of Set 10 | port hedland
# Processing Record 9 of Set 10 | kurilsk
# Processing Record 10 of Set 10 | sungurlu
# Processing Record 11 of Set 10 | lagoa
# Processing Record 12 of Set 10 | at-bashi
# Processing Record 13 of Set 10 | miraflores
# Processing Record 14 of Set 10 | asandh
# Processing Record 15 of Set 10 | da lat
# Processing Record 16 of Set 10 | eskisehir
# Processing Record 17 of Set 10 | palana
# Processing Record 18 of Set 10 | sechura
# City not found. Skipping...
# Processing Record 20 of Set 10 | galesong
# Processing Record 21 of Set 10 | inta
# Processing Record 22 of Set 10 | vrangel
# Processing Record 23 of Set 10 | oktyabrskoye
# Processing Record 24 of Set 10 | carmo do rio verde
# Processing Record 25 of Set 10 | santa cruz cabralia
# Processing Record 26 of Set 10 | uray
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 10 | kampong cham
# Processing Record 30 of Set 10 | pital
# Processing Record 31 of Set 10 | seymchan
# City not found. Skipping...
# Processing Record 33 of Set 10 | whitefish
# Processing Record 34 of Set 10 | abha
# Processing Record 35 of Set 10 | harper
# Processing Record 36 of Set 10 | necochea
# Processing Record 37 of Set 10 | sandnessjoen
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | verkhnevilyuysk
# Processing Record 40 of Set 10 | arkhara
# Processing Record 41 of Set 10 | talara
# Processing Record 42 of Set 10 | kosh-agach
# Processing Record 43 of Set 10 | kumluca
# Processing Record 44 of Set 10 | pervomayskiy
# Processing Record 45 of Set 10 | krasnyy yar
# Processing Record 46 of Set 10 | kununurra
# Processing Record 47 of Set 10 | santa rosa
# Processing Record 48 of Set 10 | trelew
# Processing Record 49 of Set 10 | takoradi
# Processing Record 50 of Set 10 | bilma
# Processing Record 1 of Set 11 | paredon
# Processing Record 2 of Set 11 | millerovo
# Processing Record 3 of Set 11 | awka
# Processing Record 4 of Set 11 | shubarshi
# Processing Record 5 of Set 11 | erzin
# Processing Record 6 of Set 11 | wadi musa
# Processing Record 7 of Set 11 | oranjemund
# Processing Record 8 of Set 11 | saint-prosper
# City not found. Skipping...
# Processing Record 10 of Set 11 | ano mera
# Processing Record 11 of Set 11 | svetlyy
# City not found. Skipping...
# Processing Record 13 of Set 11 | miri
# City not found. Skipping...
# Processing Record 15 of Set 11 | san quintin
# Processing Record 16 of Set 11 | valparaiso
# Processing Record 17 of Set 11 | touros
# Processing Record 18 of Set 11 | akyab
# Processing Record 19 of Set 11 | guadalajara
# Processing Record 20 of Set 11 | sorong
# Processing Record 21 of Set 11 | ambulu
# Processing Record 22 of Set 11 | naryan-mar
# Processing Record 23 of Set 11 | edd
# Processing Record 24 of Set 11 | valleyview
# Processing Record 25 of Set 11 | oistins
# Processing Record 26 of Set 11 | yarkovo
# Processing Record 27 of Set 11 | mazagao
# Processing Record 28 of Set 11 | comodoro rivadavia
# Processing Record 29 of Set 11 | girne
# Processing Record 30 of Set 11 | roald
# Processing Record 31 of Set 11 | misratah
# Processing Record 32 of Set 11 | harlingen
# Processing Record 33 of Set 11 | westport
# Processing Record 34 of Set 11 | bayan
# Processing Record 35 of Set 11 | loukhi
# Processing Record 36 of Set 11 | yanaul
# Processing Record 37 of Set 11 | kankan
# Processing Record 38 of Set 11 | dubbo
# Processing Record 39 of Set 11 | rocha
# Processing Record 40 of Set 11 | tilichiki
# Processing Record 41 of Set 11 | buchanan
# Processing Record 42 of Set 11 | aracaju
# Processing Record 43 of Set 11 | kruisfontein
# Processing Record 44 of Set 11 | rocky mountain house
# Processing Record 45 of Set 11 | yavoriv
# Processing Record 46 of Set 11 | siniscola
# Processing Record 47 of Set 11 | te anau
# Processing Record 48 of Set 11 | kamina
# Processing Record 49 of Set 11 | slave lake
# Processing Record 50 of Set 11 | penticton
# Processing Record 1 of Set 12 | liku
# Processing Record 2 of Set 12 | beringovskiy
# Processing Record 3 of Set 12 | matucana
# Processing Record 4 of Set 12 | hualmay
# Processing Record 5 of Set 12 | vila franca do campo
# Processing Record 6 of Set 12 | enshi
# Processing Record 7 of Set 12 | oxford
# Processing Record 8 of Set 12 | niimi
# Processing Record 9 of Set 12 | ajaccio
# Processing Record 10 of Set 12 | bachaquero
# Processing Record 11 of Set 12 | inza
# Processing Record 12 of Set 12 | vostok
# Processing Record 13 of Set 12 | minuri
# Processing Record 14 of Set 12 | rabat
# Processing Record 15 of Set 12 | troitskoye
# Processing Record 16 of Set 12 | tabuk
# Processing Record 17 of Set 12 | mayumba
# Processing Record 18 of Set 12 | fengcheng
# Processing Record 19 of Set 12 | castrovillari
# Processing Record 20 of Set 12 | belyy yar
# Processing Record 21 of Set 12 | orlik
# Processing Record 22 of Set 12 | waingapu
# Processing Record 23 of Set 12 | atambua
# Processing Record 24 of Set 12 | shipitsyno
# Processing Record 25 of Set 12 | chokurdakh
# City not found. Skipping...
# Processing Record 27 of Set 12 | urubamba
# Processing Record 28 of Set 12 | sao filipe
# Processing Record 29 of Set 12 | shanghai
# Processing Record 30 of Set 12 | tsabong
# Processing Record 31 of Set 12 | margate
# Processing Record 32 of Set 12 | salalah
# Processing Record 33 of Set 12 | kaeng khoi
# Processing Record 34 of Set 12 | saint-francois
# Processing Record 35 of Set 12 | manyana
# Processing Record 36 of Set 12 | casa nova
# Processing Record 37 of Set 12 | san nicolas
# Processing Record 38 of Set 12 | sakakah
# Processing Record 39 of Set 12 | biak
# City not found. Skipping...
# Processing Record 41 of Set 12 | beidao
# Processing Record 42 of Set 12 | pordim
# City not found. Skipping...
# Processing Record 44 of Set 12 | namibe
# Processing Record 45 of Set 12 | borskoye
# Processing Record 46 of Set 12 | babai
# Processing Record 47 of Set 12 | iisalmi
# Processing Record 48 of Set 12 | tsaratanana
# Processing Record 49 of Set 12 | jijiga
# Processing Record 50 of Set 12 | gold coast
# Processing Record 1 of Set 13 | sorland
# Processing Record 2 of Set 13 | kayerkan
# Processing Record 3 of Set 13 | tazovskiy
# Processing Record 4 of Set 13 | nouadhibou
# Processing Record 5 of Set 13 | reynosa
# Processing Record 6 of Set 13 | nantucket
# Processing Record 7 of Set 13 | harrogate
# Processing Record 8 of Set 13 | bosaso
# Processing Record 9 of Set 13 | pasighat
# Processing Record 10 of Set 13 | seabra
# Processing Record 11 of Set 13 | manzanillo
# City not found. Skipping...
# Processing Record 13 of Set 13 | zapolyarnyy
# Processing Record 14 of Set 13 | araouane
# Processing Record 15 of Set 13 | tual
# Processing Record 16 of Set 13 | ryotsu
# Processing Record 17 of Set 13 | tutoia
# Processing Record 18 of Set 13 | koungou
# Processing Record 19 of Set 13 | coquimbo
# Processing Record 20 of Set 13 | nabire
# City not found. Skipping...
# Processing Record 22 of Set 13 | jiexiu
# Processing Record 23 of Set 13 | la gomera
# Processing Record 24 of Set 13 | komsomolskiy
# Processing Record 25 of Set 13 | fez
# Processing Record 26 of Set 13 | yanam
# Processing Record 27 of Set 13 | faya
# Processing Record 28 of Set 13 | bogovarovo
# Processing Record 29 of Set 13 | fort nelson
# Processing Record 30 of Set 13 | asau
# City not found. Skipping...
# Processing Record 32 of Set 13 | sakaiminato
# Processing Record 33 of Set 13 | pundaguitan
# City not found. Skipping...
# Processing Record 35 of Set 13 | muros
# Processing Record 36 of Set 13 | tucumcari
# Processing Record 37 of Set 13 | ostrovnoy
# Processing Record 38 of Set 13 | nyurba
# Processing Record 39 of Set 13 | puerto escondido
# Processing Record 40 of Set 13 | bonthe
# City not found. Skipping...
# Processing Record 42 of Set 13 | brae
# City not found. Skipping...
# Processing Record 44 of Set 13 | prainha
# Processing Record 45 of Set 13 | zagreb
# Processing Record 46 of Set 13 | zhigansk
# Processing Record 47 of Set 13 | syamzha
# Processing Record 48 of Set 13 | korla
# Processing Record 49 of Set 13 | la esperanza
# Processing Record 50 of Set 13 | quatre cocos
# Processing Record 1 of Set 14 | batemans bay
# Processing Record 2 of Set 14 | raudeberg
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating DataFrame
city_wx_df = pd.DataFrame({
    'City':city_wx,
    'Lat':lat, 
    'Lng':lon,
    'Max Temp':maxTemp, 
    'Humidity':humidity, 
    'Cloudiness':cloudiness,
    'Wind Speed':windSpeed, 
    'Country':country, 
    'Date':date
})

# Printing DataFrame
city_wx_df.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      aksu  41.12   80.26     18.73        95          75        0.34
# 1    hobart -42.88  147.33     62.01        44          40       17.22
# 2    neiafu -18.65 -173.98     84.20        74          75       13.87
# 3  sobolevo  54.43   31.90     19.98        91           0        9.91
# 4    bethel  41.37  -73.41     33.01        97          75        5.82
#
#   Country        Date
# 0      CN  1607567156
# 1      AU  1607566837
# 2      TO  1607567310
# 3      RU  1607567310
# 4      US  1607567194

# %%
# Creating CSV File
city_wx_df.to_csv('../output_data/cities.csv')

# %%
# Reading in CSV File
filepath = '../output_data/cities.csv'
f = pd.read_csv(filepath)
df = pd.DataFrame(f)
df = df.drop(columns=['Unnamed: 0']) # Dropping Column

df.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      aksu  41.12   80.26     18.73        95          75        0.34
# 1    hobart -42.88  147.33     62.01        44          40       17.22
# 2    neiafu -18.65 -173.98     84.20        74          75       13.87
# 3  sobolevo  54.43   31.90     19.98        91           0        9.91
# 4    bethel  41.37  -73.41     33.01        97          75        5.82
#
#   Country        Date
# 0      CN  1607567156
# 1      AU  1607566837
# 2      TO  1607567310
# 3      RU  1607567310
# 4      US  1607567194

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Printing Overview of Data
df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  592.000000  592.000000  592.000000  592.000000  592.000000  592.000000
# mean    20.969358   20.616385   50.326605   76.454392   52.288851    7.374223
# std     32.848308   89.364254   29.306223   18.051007   39.868939    5.456486
# min    -54.800000 -175.200000  -40.920000    7.000000    0.000000    0.340000
# 25%     -6.145000  -57.975000   31.747500   69.000000    2.000000    3.360000
# 50%     25.485000   25.760000   59.000000   81.000000   59.500000    5.820000
# 75%     49.435000  102.387500   74.040000   89.000000   90.000000   10.290000
# max     78.220000  179.320000   98.600000  100.000000  100.000000   39.150000
#
#                Date
# count  5.920000e+02
# mean   1.607568e+09
# std    3.426327e+02
# min    1.607567e+09
# 25%    1.607567e+09
# 50%    1.607568e+09
# 75%    1.607568e+09
# max    1.607568e+09

# %%
# Inspecting Data for Humidity Greater than 100%
maxHumidity = df['Humidity'].max()

# If Humidity Greater than 100%, Create DataFrame with Humidity <=100%
if maxHumidity > 100:
    df = df.loc[df['Humidity']<=100]
    df = pd.DataFrame(df)
    print(df)
else:
    print('No Humidity Over 100%')
# Out:
# No Humidity Over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Temperature vs Latitude
df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temp ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig1.png')

# %% [markdown]
# This plot is analyzing the relationship of surface temperatures across different latitudes.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Humidity vs Latitude
df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig2.png')

# %% [markdown]
# This plot is analyzing the relationship of surface humidity across different latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Cloudiness vs Latitude
df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloud Coverage ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig3.png')

# %% [markdown]
# This plot is analyzing the relationship of cloud coverage across different latitudes. As a meteorologist, I find this plot to be most intriguing because you can almost see atmospheric circulation across the 0, 30, and 60 degree latitudes. For example, the Inter Tropical Convergence Zone (ITCZ) is located around the equator. I won't divulge into the why, but locations on or around the equator will almost always have some form of cloud coverage. This can clearly be seen in our plot where there is a "hole" around the 0 degree latitude. In contrast, latitudes around 30 degrees usually have little to no cloud coverage. This is easily depicted in the plot shown above, where there is a cluster of 0% cloud coverage around 30 degrees.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Wind Speed vs Latitude
df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig4.png')

# %% [markdown]
# This plot is analyzing the relationship between surface wind speeds across different latitudes. Overall, it looks like surface winds range from 0 to 10 mph. Similar to the humidity plot, note the higher concentration of wind speeds across the northern latitudes. This may simply have to do with the availability of data since the land to ocean ratio is larger in the northern hemisphere than the southern hemisphere.

# %% [markdown]
# ## Linear Regression

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Max Temp'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Temp vs Latitude
northHem_df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Max Temp ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,-20), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: -0.87.

# %% [markdown]
# In the Northern Hemisphere, there will always be a negative linear relationship between surface temperature and latitude. This statement can be depicted by the plot above and the strong, negative rvalue of -0.87. In addition, during the time of year the rate of the slope will change. For example, during the winter months the slope will be steeper and shallow in around the summer.  Due to the relationship of temperatures and latitude, temperatures will always max around the 0 degree latitude.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Max Temp'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Temp vs Latitude
southHem_df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Max Temp ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-30,50), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.53.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# In the Southern Hemisphere, there will always be a positive linear relationship between surface temperature and latitude. This statement can be depicted by the plot above and the moderate, positive rvalue of 0.53. In addition, during the time of year the rate of the slope will change. For example, during the winter months the slope will be steeper and shallow in around the summer. Due to the relationship of temperatures and latitude, temperatures will always max around the 0 degree latitude.

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Humidity'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Humidity vs Latitude
northHem_df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Humidity ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,5), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.37.

# %% [markdown]
# The linear regression model and rvalue would suggest a weak, positive relationship between humidity and latitude. Overall, surface humidity is most concentrated between 60-100%.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Humidity'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Humidity vs Latitude
southHem_df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Humidity ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-25,30), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.21.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# The linear regression model and rvalue would suggest a weak, positive relationship between humidity and latitude. Overall, surface humidity is most concentrated between 60-100%.
#
# Note that in both humidity plots for the Northern and Southern Hemisphere there is a weak, positive relationship.

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Cloudiness'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Cloudiness vs Latitude
northHem_df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Cloud Coverage (%)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Cloud Coverage ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(45,20), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.26.

# %% [markdown]
# The data would suggest a very weak, positive relationship amoung cloud coverage and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Cloudiness'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Cloudiness vs Latitude
southHem_df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Cloud Coverage (%)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Cloud Coverage ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-50,60), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.34.

# %% [markdown]
# The data would suggest a very weak, positive relationship amoung cloud coverage and latitude. Note that in both cloud coverage plots for the Northern and Southern Hemisphere there is a weak, positive relationship.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Wind Speed'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Wind vs Latitude
northHem_df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Wind Speed ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,30), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.11.

# %% [markdown]
# According to the rvalue, there is no linear relationship amoung wind speed and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Wind Speed'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Wind vs Latitude
southHem_df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Wind Speed ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-30,20), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: -0.25.

# %% [markdown]
# According to the rvalue, there is no linear relationship amoung wind speed and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

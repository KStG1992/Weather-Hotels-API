# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
#Building Query URL
query_url = f"{base_url}appid={weather_api_key}&q="

# %%
# Creating Empty Lists
city_wx = []
lat = []
lon = []
maxTemp = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

# Using a For Loop to Make Successive API Calls
record_count = 1
set_count = 1

print('Beginning Data Retrieval')
print('------------------------')

# Loop Through Each City
# OpenWeather API will Allow 60 Calls/Min
# The Counter and .sleep Method will Us to Freely Call Data
for city in cities:
    if record_count >= 50:
        time.sleep(60)
        record_count = 0
        set_count += 1

    # Making Requests        
    response = requests.get(query_url + city + '&units=imperial').json()
    record_count += 1
   
    # Using Try/Except to Grab Variables if Available
    try:
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_wx.append(city)
        print(f'Processing Record {record_count} of Set {set_count} | {city}')
    except KeyError:
        print('City not found. Skipping...')
print('------------------------')
print('Data Retrieval Complete')
print('------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | tezu
# City not found. Skipping...
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | surt
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | palmer
# Processing Record 10 of Set 1 | isangel
# Processing Record 11 of Set 1 | dudinka
# Processing Record 12 of Set 1 | prince rupert
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | yulara
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | tuatapere
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | mayo
# Processing Record 27 of Set 1 | clyde river
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | svetlogorsk
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | tongling
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | hobyo
# Processing Record 39 of Set 1 | saint anthony
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | fortuna
# Processing Record 44 of Set 1 | marawi
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | alofi
# Processing Record 47 of Set 1 | santa maria do suacui
# Processing Record 48 of Set 1 | los llanos de aridane
# Processing Record 49 of Set 1 | moussoro
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | grindavik
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | ixtapa
# City not found. Skipping...
# Processing Record 8 of Set 2 | meulaboh
# Processing Record 9 of Set 2 | thonon-les-bains
# Processing Record 10 of Set 2 | vetluga
# Processing Record 11 of Set 2 | bonavista
# Processing Record 12 of Set 2 | leh
# Processing Record 13 of Set 2 | grand baie
# City not found. Skipping...
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | salta
# Processing Record 17 of Set 2 | tazovskiy
# Processing Record 18 of Set 2 | bandarbeyla
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | el campo
# Processing Record 22 of Set 2 | college
# Processing Record 23 of Set 2 | arkhangelskoye
# Processing Record 24 of Set 2 | erzin
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | hopfgarten
# Processing Record 27 of Set 2 | sao miguel do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | qandala
# Processing Record 33 of Set 2 | inirida
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | porto empedocle
# Processing Record 39 of Set 2 | las vegas
# Processing Record 40 of Set 2 | rania
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | takoradi
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | bilma
# City not found. Skipping...
# Processing Record 47 of Set 2 | dingle
# Processing Record 48 of Set 2 | byron bay
# Processing Record 49 of Set 2 | te anau
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | maroantsetra
# Processing Record 2 of Set 3 | idil
# Processing Record 3 of Set 3 | ketchikan
# Processing Record 4 of Set 3 | henties bay
# Processing Record 5 of Set 3 | fuxin
# Processing Record 6 of Set 3 | chake chake
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | caxias
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | grand-lahou
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | hailar
# Processing Record 13 of Set 3 | ahipara
# Processing Record 14 of Set 3 | carnarvon
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | abu samrah
# Processing Record 18 of Set 3 | la paz
# Processing Record 19 of Set 3 | villagarzon
# Processing Record 20 of Set 3 | gospic
# Processing Record 21 of Set 3 | les cayes
# Processing Record 22 of Set 3 | zemio
# Processing Record 23 of Set 3 | ostrovnoy
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | san quintin
# Processing Record 26 of Set 3 | santiago
# Processing Record 27 of Set 3 | escarcega
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | pokhvistnevo
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | guangshui
# Processing Record 33 of Set 3 | mustasaari
# City not found. Skipping...
# Processing Record 35 of Set 3 | gorin
# Processing Record 36 of Set 3 | altinopolis
# City not found. Skipping...
# Processing Record 38 of Set 3 | pangkalanbuun
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | sitka
# Processing Record 41 of Set 3 | grafton
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | korla
# Processing Record 44 of Set 3 | mataura
# Processing Record 45 of Set 3 | fort abbas
# Processing Record 46 of Set 3 | bredasdorp
# City not found. Skipping...
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | wilmington
# Processing Record 50 of Set 3 | abbeville
# City not found. Skipping...
# Processing Record 2 of Set 4 | saint andrews
# Processing Record 3 of Set 4 | yichang
# Processing Record 4 of Set 4 | sikeston
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | sept-iles
# City not found. Skipping...
# Processing Record 9 of Set 4 | carlisle
# Processing Record 10 of Set 4 | lalibela
# Processing Record 11 of Set 4 | san ramon de la nueva oran
# Processing Record 12 of Set 4 | quimperle
# Processing Record 13 of Set 4 | georgetown
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | liepaja
# Processing Record 16 of Set 4 | ramgarh
# Processing Record 17 of Set 4 | koygorodok
# Processing Record 18 of Set 4 | konstantinovka
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | peace river
# Processing Record 21 of Set 4 | kasongo-lunda
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | ginir
# Processing Record 24 of Set 4 | poum
# City not found. Skipping...
# Processing Record 26 of Set 4 | taksimo
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | namibe
# City not found. Skipping...
# Processing Record 31 of Set 4 | flinders
# City not found. Skipping...
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | narodychi
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | san cristobal
# Processing Record 37 of Set 4 | katherine
# City not found. Skipping...
# Processing Record 39 of Set 4 | altoona
# Processing Record 40 of Set 4 | saurimo
# Processing Record 41 of Set 4 | savannah bight
# Processing Record 42 of Set 4 | chara
# Processing Record 43 of Set 4 | fort frances
# City not found. Skipping...
# Processing Record 45 of Set 4 | clarence town
# Processing Record 46 of Set 4 | fort nelson
# Processing Record 47 of Set 4 | kununurra
# Processing Record 48 of Set 4 | robertsport
# Processing Record 49 of Set 4 | qaqortoq
# Processing Record 50 of Set 4 | verkhoyansk
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | morden
# Processing Record 3 of Set 5 | lavrentiya
# Processing Record 4 of Set 5 | wajima
# Processing Record 5 of Set 5 | emba
# Processing Record 6 of Set 5 | evensk
# Processing Record 7 of Set 5 | banda aceh
# Processing Record 8 of Set 5 | vaitape
# Processing Record 9 of Set 5 | faya
# Processing Record 10 of Set 5 | fremont
# Processing Record 11 of Set 5 | nishihara
# Processing Record 12 of Set 5 | ulladulla
# Processing Record 13 of Set 5 | beringovskiy
# Processing Record 14 of Set 5 | neka
# Processing Record 15 of Set 5 | haines junction
# Processing Record 16 of Set 5 | srandakan
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | klaksvik
# Processing Record 20 of Set 5 | berlevag
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | constitucion
# Processing Record 23 of Set 5 | sao gabriel da cachoeira
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | tarragona
# Processing Record 26 of Set 5 | pochutla
# Processing Record 27 of Set 5 | provost
# Processing Record 28 of Set 5 | tamasopo
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | trincomalee
# City not found. Skipping...
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | cabedelo
# Processing Record 34 of Set 5 | axim
# Processing Record 35 of Set 5 | zelenokumsk
# City not found. Skipping...
# Processing Record 37 of Set 5 | pacific grove
# Processing Record 38 of Set 5 | valparaiso
# Processing Record 39 of Set 5 | honningsvag
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | chimbote
# Processing Record 42 of Set 5 | gravdal
# Processing Record 43 of Set 5 | cherskiy
# Processing Record 44 of Set 5 | geraldton
# Processing Record 45 of Set 5 | yopal
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | carndonagh
# City not found. Skipping...
# Processing Record 49 of Set 5 | andros town
# Processing Record 50 of Set 5 | ilebo
# Processing Record 1 of Set 6 | cairns
# Processing Record 2 of Set 6 | nyurba
# Processing Record 3 of Set 6 | dodge city
# Processing Record 4 of Set 6 | sao jose da coroa grande
# Processing Record 5 of Set 6 | mehamn
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | campoverde
# Processing Record 8 of Set 6 | mumford
# Processing Record 9 of Set 6 | maraa
# Processing Record 10 of Set 6 | gouyave
# Processing Record 11 of Set 6 | yilan
# City not found. Skipping...
# Processing Record 13 of Set 6 | novobirilyussy
# Processing Record 14 of Set 6 | aklavik
# Processing Record 15 of Set 6 | mangan
# Processing Record 16 of Set 6 | rawson
# Processing Record 17 of Set 6 | ingham
# Processing Record 18 of Set 6 | maldonado
# Processing Record 19 of Set 6 | coquimbo
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | adrar
# Processing Record 22 of Set 6 | fare
# Processing Record 23 of Set 6 | abha
# Processing Record 24 of Set 6 | skibotn
# City not found. Skipping...
# Processing Record 26 of Set 6 | george town
# Processing Record 27 of Set 6 | vila
# Processing Record 28 of Set 6 | sassari
# Processing Record 29 of Set 6 | tutoia
# Processing Record 30 of Set 6 | port augusta
# Processing Record 31 of Set 6 | lata
# Processing Record 32 of Set 6 | faaborg
# Processing Record 33 of Set 6 | severo-kurilsk
# Processing Record 34 of Set 6 | kuruman
# Processing Record 35 of Set 6 | xian
# City not found. Skipping...
# Processing Record 37 of Set 6 | esso
# Processing Record 38 of Set 6 | padang
# Processing Record 39 of Set 6 | nikolskoye
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | sicamous
# Processing Record 42 of Set 6 | sioux lookout
# Processing Record 43 of Set 6 | pevek
# Processing Record 44 of Set 6 | pirgos
# Processing Record 45 of Set 6 | emborion
# Processing Record 46 of Set 6 | amapa
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | mendoza
# Processing Record 49 of Set 6 | terra santa
# Processing Record 50 of Set 6 | vardo
# Processing Record 1 of Set 7 | puerto leguizamo
# Processing Record 2 of Set 7 | half moon bay
# Processing Record 3 of Set 7 | wangkui
# Processing Record 4 of Set 7 | cadillac
# Processing Record 5 of Set 7 | san lazaro
# Processing Record 6 of Set 7 | port macquarie
# Processing Record 7 of Set 7 | vila franca do campo
# Processing Record 8 of Set 7 | phuket
# City not found. Skipping...
# Processing Record 10 of Set 7 | tual
# Processing Record 11 of Set 7 | kamenka
# Processing Record 12 of Set 7 | sicuani
# Processing Record 13 of Set 7 | nelson bay
# Processing Record 14 of Set 7 | xichang
# Processing Record 15 of Set 7 | hervey bay
# Processing Record 16 of Set 7 | douglas
# Processing Record 17 of Set 7 | burgos
# Processing Record 18 of Set 7 | antalaha
# Processing Record 19 of Set 7 | covington
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | kazanka
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | saskylakh
# Processing Record 24 of Set 7 | esperance
# Processing Record 25 of Set 7 | longyearbyen
# Processing Record 26 of Set 7 | tateyama
# Processing Record 27 of Set 7 | kudahuvadhoo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 7 | ponta do sol
# Processing Record 31 of Set 7 | jerez
# Processing Record 32 of Set 7 | opuwo
# Processing Record 33 of Set 7 | tamale
# Processing Record 34 of Set 7 | nyanguge
# Processing Record 35 of Set 7 | impfondo
# Processing Record 36 of Set 7 | fairmont
# Processing Record 37 of Set 7 | kolo
# City not found. Skipping...
# Processing Record 39 of Set 7 | anadyr
# Processing Record 40 of Set 7 | ugoofaaru
# Processing Record 41 of Set 7 | bambous virieux
# Processing Record 42 of Set 7 | meadow lake
# Processing Record 43 of Set 7 | matara
# Processing Record 44 of Set 7 | suntar
# Processing Record 45 of Set 7 | najran
# Processing Record 46 of Set 7 | yeniseysk
# Processing Record 47 of Set 7 | pangnirtung
# Processing Record 48 of Set 7 | sur
# Processing Record 49 of Set 7 | kaeo
# Processing Record 50 of Set 7 | metapan
# Processing Record 1 of Set 8 | muriwai beach
# Processing Record 2 of Set 8 | urumqi
# Processing Record 3 of Set 8 | libertador general san martin
# Processing Record 4 of Set 8 | kieta
# Processing Record 5 of Set 8 | penzance
# Processing Record 6 of Set 8 | tambo grande
# Processing Record 7 of Set 8 | basco
# Processing Record 8 of Set 8 | tsabong
# Processing Record 9 of Set 8 | celle
# Processing Record 10 of Set 8 | chicama
# Processing Record 11 of Set 8 | michigan city
# Processing Record 12 of Set 8 | snyder
# Processing Record 13 of Set 8 | brokopondo
# Processing Record 14 of Set 8 | lewiston
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | myitkyina
# Processing Record 17 of Set 8 | bansko
# Processing Record 18 of Set 8 | christchurch
# Processing Record 19 of Set 8 | maralal
# Processing Record 20 of Set 8 | mogadishu
# Processing Record 21 of Set 8 | cidreira
# Processing Record 22 of Set 8 | northam
# Processing Record 23 of Set 8 | general roca
# City not found. Skipping...
# Processing Record 25 of Set 8 | santa maria
# Processing Record 26 of Set 8 | rafaela
# Processing Record 27 of Set 8 | nirmal
# City not found. Skipping...
# Processing Record 29 of Set 8 | tema
# City not found. Skipping...
# Processing Record 31 of Set 8 | quatre cocos
# Processing Record 32 of Set 8 | sulangan
# Processing Record 33 of Set 8 | ilulissat
# Processing Record 34 of Set 8 | kahului
# City not found. Skipping...
# Processing Record 36 of Set 8 | eureka
# Processing Record 37 of Set 8 | koundara
# Processing Record 38 of Set 8 | beloha
# City not found. Skipping...
# Processing Record 40 of Set 8 | lebanon
# City not found. Skipping...
# Processing Record 42 of Set 8 | belmonte
# Processing Record 43 of Set 8 | noyabrsk
# Processing Record 44 of Set 8 | serenje
# Processing Record 45 of Set 8 | thunder bay
# City not found. Skipping...
# Processing Record 47 of Set 8 | dalby
# Processing Record 48 of Set 8 | udachnyy
# City not found. Skipping...
# Processing Record 50 of Set 8 | soyo
# Processing Record 1 of Set 9 | saint-louis
# Processing Record 2 of Set 9 | sao filipe
# Processing Record 3 of Set 9 | rio rancho
# Processing Record 4 of Set 9 | burlington
# Processing Record 5 of Set 9 | champerico
# Processing Record 6 of Set 9 | alexandria
# Processing Record 7 of Set 9 | rochegda
# Processing Record 8 of Set 9 | smolenka
# Processing Record 9 of Set 9 | sambava
# Processing Record 10 of Set 9 | coahuayana
# City not found. Skipping...
# Processing Record 12 of Set 9 | imeni poliny osipenko
# Processing Record 13 of Set 9 | guerrero negro
# City not found. Skipping...
# Processing Record 15 of Set 9 | labuhan
# Processing Record 16 of Set 9 | mahendranagar
# Processing Record 17 of Set 9 | soddy-daisy
# Processing Record 18 of Set 9 | tessalit
# Processing Record 19 of Set 9 | kristinehamn
# Processing Record 20 of Set 9 | ballina
# Processing Record 21 of Set 9 | skjervoy
# Processing Record 22 of Set 9 | havoysund
# Processing Record 23 of Set 9 | berkeley heights
# Processing Record 24 of Set 9 | dhidhdhoo
# Processing Record 25 of Set 9 | batagay
# Processing Record 26 of Set 9 | saint-joseph
# Processing Record 27 of Set 9 | san nicolas
# Processing Record 28 of Set 9 | camaguey
# Processing Record 29 of Set 9 | haizhou
# Processing Record 30 of Set 9 | canton
# Processing Record 31 of Set 9 | olafsvik
# City not found. Skipping...
# Processing Record 33 of Set 9 | acajutla
# Processing Record 34 of Set 9 | simao
# Processing Record 35 of Set 9 | saint-prosper
# Processing Record 36 of Set 9 | marzuq
# Processing Record 37 of Set 9 | vikhorevka
# Processing Record 38 of Set 9 | portland
# Processing Record 39 of Set 9 | shelburne
# City not found. Skipping...
# Processing Record 41 of Set 9 | mareeba
# Processing Record 42 of Set 9 | anloga
# Processing Record 43 of Set 9 | naze
# Processing Record 44 of Set 9 | snasa
# Processing Record 45 of Set 9 | zhigansk
# Processing Record 46 of Set 9 | kotelnikovo
# Processing Record 47 of Set 9 | shache
# City not found. Skipping...
# Processing Record 49 of Set 9 | rypefjord
# Processing Record 50 of Set 9 | sandwich
# Processing Record 1 of Set 10 | petropavlovskoye
# Processing Record 2 of Set 10 | kavieng
# Processing Record 3 of Set 10 | laguna
# Processing Record 4 of Set 10 | svetlyy
# Processing Record 5 of Set 10 | fairbanks
# City not found. Skipping...
# Processing Record 7 of Set 10 | jiayuguan
# Processing Record 8 of Set 10 | komsomolskiy
# Processing Record 9 of Set 10 | vanimo
# City not found. Skipping...
# Processing Record 11 of Set 10 | cordoba
# City not found. Skipping...
# Processing Record 13 of Set 10 | narasannapeta
# Processing Record 14 of Set 10 | tabou
# Processing Record 15 of Set 10 | cockburn town
# Processing Record 16 of Set 10 | mindelo
# Processing Record 17 of Set 10 | gilbues
# Processing Record 18 of Set 10 | flin flon
# Processing Record 19 of Set 10 | araouane
# Processing Record 20 of Set 10 | lujiang
# Processing Record 21 of Set 10 | conceicao do araguaia
# Processing Record 22 of Set 10 | sinnamary
# Processing Record 23 of Set 10 | inta
# Processing Record 24 of Set 10 | ilhabela
# Processing Record 25 of Set 10 | cuyali
# Processing Record 26 of Set 10 | cascais
# Processing Record 27 of Set 10 | mungaoli
# Processing Record 28 of Set 10 | aquin
# Processing Record 29 of Set 10 | nakatsugawa
# Processing Record 30 of Set 10 | eravur
# Processing Record 31 of Set 10 | sakakah
# Processing Record 32 of Set 10 | gizo
# Processing Record 33 of Set 10 | bilokurakyne
# Processing Record 34 of Set 10 | victor harbor
# Processing Record 35 of Set 10 | fort-shevchenko
# Processing Record 36 of Set 10 | wyndham
# Processing Record 37 of Set 10 | isla mujeres
# Processing Record 38 of Set 10 | kisarawe
# Processing Record 39 of Set 10 | bako
# Processing Record 40 of Set 10 | banjar
# Processing Record 41 of Set 10 | partizanskoye
# Processing Record 42 of Set 10 | lerwick
# Processing Record 43 of Set 10 | belaya gora
# Processing Record 44 of Set 10 | killybegs
# City not found. Skipping...
# Processing Record 46 of Set 10 | okakarara
# Processing Record 47 of Set 10 | santa cruz de la palma
# Processing Record 48 of Set 10 | la asuncion
# Processing Record 49 of Set 10 | novyy urengoy
# Processing Record 50 of Set 10 | namatanai
# Processing Record 1 of Set 11 | bitung
# Processing Record 2 of Set 11 | vuktyl
# Processing Record 3 of Set 11 | ranfurly
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | el astillero
# Processing Record 6 of Set 11 | bagan
# Processing Record 7 of Set 11 | odweyne
# Processing Record 8 of Set 11 | aurad
# City not found. Skipping...
# Processing Record 10 of Set 11 | westport
# Processing Record 11 of Set 11 | high level
# Processing Record 12 of Set 11 | moose factory
# Processing Record 13 of Set 11 | passo de camaragibe
# City not found. Skipping...
# Processing Record 15 of Set 11 | corinth
# Processing Record 16 of Set 11 | dambulla
# City not found. Skipping...
# Processing Record 18 of Set 11 | marsa matruh
# Processing Record 19 of Set 11 | maymyo
# Processing Record 20 of Set 11 | ambulu
# Processing Record 21 of Set 11 | shubarkuduk
# Processing Record 22 of Set 11 | bilibino
# Processing Record 23 of Set 11 | pahrump
# Processing Record 24 of Set 11 | canutama
# Processing Record 25 of Set 11 | dwarka
# Processing Record 26 of Set 11 | brownwood
# Processing Record 27 of Set 11 | vieste
# Processing Record 28 of Set 11 | qiongshan
# Processing Record 29 of Set 11 | vangaindrano
# City not found. Skipping...
# Processing Record 31 of Set 11 | port moresby
# Processing Record 32 of Set 11 | birobidzhan
# Processing Record 33 of Set 11 | saint-leu
# Processing Record 34 of Set 11 | le port
# Processing Record 35 of Set 11 | ishigaki
# Processing Record 36 of Set 11 | maketu
# Processing Record 37 of Set 11 | husavik
# Processing Record 38 of Set 11 | nakambala
# Processing Record 39 of Set 11 | mao
# City not found. Skipping...
# Processing Record 41 of Set 11 | bartlesville
# Processing Record 42 of Set 11 | sirnak
# City not found. Skipping...
# Processing Record 44 of Set 11 | guadalupe y calvo
# Processing Record 45 of Set 11 | montepuez
# Processing Record 46 of Set 11 | sayyan
# City not found. Skipping...
# Processing Record 48 of Set 11 | praia
# Processing Record 49 of Set 11 | hedaru
# Processing Record 50 of Set 11 | warwick
# City not found. Skipping...
# Processing Record 2 of Set 12 | mutis
# Processing Record 3 of Set 12 | wajir
# Processing Record 4 of Set 12 | road town
# Processing Record 5 of Set 12 | brae
# Processing Record 6 of Set 12 | bandiagara
# Processing Record 7 of Set 12 | tulagi
# Processing Record 8 of Set 12 | dakoro
# City not found. Skipping...
# Processing Record 10 of Set 12 | port keats
# Processing Record 11 of Set 12 | kysyl-syr
# Processing Record 12 of Set 12 | along
# Processing Record 13 of Set 12 | marquette
# Processing Record 14 of Set 12 | nouadhibou
# Processing Record 15 of Set 12 | kruisfontein
# Processing Record 16 of Set 12 | carutapera
# Processing Record 17 of Set 12 | khuzhir
# Processing Record 18 of Set 12 | tukrah
# Processing Record 19 of Set 12 | lagoa
# Processing Record 20 of Set 12 | aranos
# City not found. Skipping...
# Processing Record 22 of Set 12 | manggar
# Processing Record 23 of Set 12 | cabo san lucas
# Processing Record 24 of Set 12 | novyy khushet
# Processing Record 25 of Set 12 | pryazha
# Processing Record 26 of Set 12 | gao
# Processing Record 27 of Set 12 | aksarka
# Processing Record 28 of Set 12 | joensuu
# Processing Record 29 of Set 12 | koutsouras
# Processing Record 30 of Set 12 | key largo
# Processing Record 31 of Set 12 | ponnani
# Processing Record 32 of Set 12 | ous
# Processing Record 33 of Set 12 | anajatuba
# Processing Record 34 of Set 12 | zhuzhou
# Processing Record 35 of Set 12 | puerto maldonado
# Processing Record 36 of Set 12 | arlit
# Processing Record 37 of Set 12 | malakal
# Processing Record 38 of Set 12 | ust-kuyga
# Processing Record 39 of Set 12 | kalvarija
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 12 | guilin
# Processing Record 43 of Set 12 | bembereke
# Processing Record 44 of Set 12 | kuusamo
# Processing Record 45 of Set 12 | riberalta
# Processing Record 46 of Set 12 | lakeway
# Processing Record 47 of Set 12 | dunedin
# Processing Record 48 of Set 12 | akyab
# City not found. Skipping...
# Processing Record 50 of Set 12 | tevriz
# Processing Record 1 of Set 13 | waingapu
# Processing Record 2 of Set 13 | kalabo
# Processing Record 3 of Set 13 | lusambo
# City not found. Skipping...
# Processing Record 5 of Set 13 | preobrazheniye
# Processing Record 6 of Set 13 | aripuana
# City not found. Skipping...
# Processing Record 8 of Set 13 | takhtamygda
# Processing Record 9 of Set 13 | tevaitoa
# Processing Record 10 of Set 13 | longjiang
# Processing Record 11 of Set 13 | methoni
# Processing Record 12 of Set 13 | cayenne
# Processing Record 13 of Set 13 | islampur
# Processing Record 14 of Set 13 | nara
# Processing Record 15 of Set 13 | machinga
# Processing Record 16 of Set 13 | melo
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating DataFrame
city_wx_df = pd.DataFrame({
    'City':city_wx,
    'Lat':lat, 
    'Lng':lon,
    'Max Temp':maxTemp, 
    'Humidity':humidity, 
    'Cloudiness':cloudiness,
    'Wind Speed':windSpeed, 
    'Country':country, 
    'Date':date
})

# Printing DataFrame
city_wx_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        chuy -33.70  -53.46     84.56        44           0        7.65
# 1        tezu  27.92   96.17     65.07        47          71        2.93
# 2  kaitangata -46.28  169.85     46.99        94         100       11.01
# 3        surt  31.21   16.59     61.18        34           0        9.89
# 4       kapaa  22.08 -159.32     71.60       100          90        5.82
#
#   Country        Date
# 0      UY  1607618582
# 1      IN  1607618582
# 2      NZ  1607618583
# 3      LY  1607618583
# 4      US  1607618583

# %%
# Creating CSV File
city_wx_df.to_csv('../output_data/cities.csv')

# %%
# Reading in CSV File
filepath = '../output_data/cities.csv'
f = pd.read_csv(filepath)
df = pd.DataFrame(f)
df = df.drop(columns=['Unnamed: 0']) # Dropping Column

df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        chuy -33.70  -53.46     84.56        44           0        7.65
# 1        tezu  27.92   96.17     65.07        47          71        2.93
# 2  kaitangata -46.28  169.85     46.99        94         100       11.01
# 3        surt  31.21   16.59     61.18        34           0        9.89
# 4       kapaa  22.08 -159.32     71.60       100          90        5.82
#
#   Country        Date
# 0      UY  1607618582
# 1      IN  1607618582
# 2      NZ  1607618583
# 3      LY  1607618583
# 4      US  1607618583

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Printing Overview of Data
df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  555.000000  555.000000  555.000000  555.000000  555.000000  555.000000
# mean    20.281622   15.402000   53.687207   72.513514   51.372973    8.040252
# std     33.053740   90.493872   29.936631   20.753263   37.490788    5.274892
# min    -54.800000 -175.200000  -41.130000   11.000000    0.000000    0.360000
# 25%     -6.705000  -68.225000   37.400000   62.000000   11.000000    4.025000
# 50%     22.790000   20.390000   62.010000   78.000000   54.000000    6.930000
# 75%     47.860000   93.645000   77.000000   88.000000   90.000000   10.725000
# max     78.220000  179.320000  102.000000  100.000000  100.000000   27.510000
#
#                Date
# count  5.550000e+02
# mean   1.607619e+09
# std    2.606809e+02
# min    1.607618e+09
# 25%    1.607619e+09
# 50%    1.607619e+09
# 75%    1.607619e+09
# max    1.607619e+09

# %%
# Inspecting Data for Humidity Greater than 100%
maxHumidity = df['Humidity'].max()

# If Humidity Greater than 100%, Create DataFrame with Humidity <=100%
if maxHumidity > 100:
    df = df.loc[df['Humidity']<=100]
    df = pd.DataFrame(df)
    print(df)
else:
    print('No Humidity Over 100%')
# Out:
# No Humidity Over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Temperature vs Latitude
df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temp ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig1.png')

# %% [markdown]
# This plot is analyzing the relationship of surface temperatures across different latitudes.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Humidity vs Latitude
df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig2.png')

# %% [markdown]
# This plot is analyzing the relationship of surface humidity across different latitudes.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Cloudiness vs Latitude
df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloud Coverage ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig3.png')

# %% [markdown]
# This plot is analyzing the relationship of cloud coverage across different latitudes. As a meteorologist, I find this plot to be most intriguing because you can almost see atmospheric circulation across the 0, 30, and 60 degree latitudes. For example, the Inter Tropical Convergence Zone (ITCZ) is located around the equator. I won't divulge into the why, but locations on or around the equator will almost always have some form of cloud coverage. This can clearly be seen in our plot where there is a "hole" around the 0 degree latitude. In contrast, latitudes around 30 degrees usually have little to no cloud coverage. This is easily depicted in the plot shown above, where there is a cluster of 0% cloud coverage around 30 degrees.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Wind Speed vs Latitude
df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)

# Labelling the Plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({title_date})')
plt.tight_layout()

# Saving Figure as PNG
plt.savefig('../output_data/Fig4.png')

# %% [markdown]
# This plot is analyzing the relationship between surface wind speeds across different latitudes. Overall, it looks like surface winds range from 0 to 10 mph. Similar to the humidity plot, note the higher concentration of wind speeds across the northern latitudes. This may simply have to do with the availability of data since the land to ocean ratio is larger in the northern hemisphere than the southern hemisphere.

# %% [markdown]
# ## Linear Regression

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Max Temp'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Temp vs Latitude
northHem_df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Max Temp ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,-20), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: -0.87.

# %% [markdown]
# In the Northern Hemisphere, there will always be a negative linear relationship between surface temperature and latitude. This statement can be depicted by the plot above and the strong, negative rvalue. In addition, during the time of year the rate of the slope will change. For example, during the winter months the slope will be steeper and shallow in around the summer.  Due to the relationship of temperatures and latitude, temperatures will always max around the 0 degree latitude.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Max Temp'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Temp vs Latitude
southHem_df.plot.scatter('Lat', 'Max Temp', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Max Temp ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-30,50), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.61.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# In the Southern Hemisphere, there will always be a positive linear relationship between surface temperature and latitude. This statement can be depicted by the plot above and the moderate, positive rvalue. In addition, during the time of year the rate of the slope will change. For example, during the winter months the slope will be steeper and shallow in around the summer. Due to the relationship of temperatures and latitude, temperatures will always max around the 0 degree latitude.

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Humidity'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Humidity vs Latitude
northHem_df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Humidity ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,5), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.41.

# %% [markdown]
# The linear regression model and rvalue would suggest a weak, positive relationship between humidity and latitude. Overall, surface humidity is most concentrated between 60-100%.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Humidity'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Humidity vs Latitude
southHem_df.plot.scatter('Lat', 'Humidity', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Humidity ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-25,30), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.09.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# The linear regression model and rvalue would suggest a weak, positive relationship between humidity and latitude. Overall, surface humidity is most concentrated between 60-100%.
#
# Note that in both humidity plots for the Northern and Southern Hemisphere there is a weak, positive relationship.

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Cloudiness'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Cloudiness vs Latitude
northHem_df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Cloud Coverage (%)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Cloud Coverage ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(45,20), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.24.

# %% [markdown]
# The data would suggest a very weak, positive relationship amoung cloud coverage and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Cloudiness'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Cloudiness vs Latitude
southHem_df.plot.scatter('Lat', 'Cloudiness', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Cloud Coverage (%)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Cloud Coverage ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-50,60), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.23.

# %% [markdown]
# The data would suggest a very weak, positive relationship amoung cloud coverage and latitude. Note that in both cloud coverage plots for the Northern and Southern Hemisphere there is a weak, positive relationship.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Greater than or Equal to 0 Degrees
northHem_df = df.loc[df['Lat']>=0,:]

# Setting Latitude as x_value
x_value = northHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(northHem_df['Lat'], northHem_df['Wind Speed'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Wind vs Latitude
northHem_df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Hemisphere\nCity Latitude vs Wind Speed ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(0,30), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: 0.08.

# %% [markdown]
# According to the rvalue, there is no linear relationship amoung wind speed and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Grabbing Data with a Latitude Less than or Equal to 0 Degrees
southHem_df = df.loc[df['Lat']<=0,:]

# Setting Latitude as x_value
x_value = southHem_df['Lat']

# Solving for Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(southHem_df['Lat'], southHem_df['Wind Speed'])

# Creating Line Equation
regress_value = x_value*slope + intercept

# Creating DateStamp that will Update with Each Call
datestamp = datestamp = time.gmtime(df['Date'][0])
title_date = f'{datestamp.tm_mon}/{datestamp.tm_mday}/{datestamp.tm_year}'

# Plotting Wind vs Latitude
southHem_df.plot.scatter('Lat', 'Wind Speed', grid=True, color='cyan', edgecolor='k', s=40)

# Plotting Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Hemisphere\nCity Latitude vs Wind Speed ({title_date})')

# Creating String of Line Equation to Overlay on Plot
line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"

# Plotting Linear Regression and Equation
plt.plot(x_value, regress_value, c='k')
plt.annotate(line_eq, xy=(-30,20), fontsize=15)

# Print rvalue
print(f'The Correlation Value is: {round(rvalue,2)}.')
# Out:
# The Correlation Value is: -0.1.

# %% [markdown]
# According to the rvalue, there is no linear relationship amoung wind speed and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
